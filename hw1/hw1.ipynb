# %% [markdown]
# # Exercise 1: Linear Regression
#
# ## Do not start the exercise until you fully understand the submission guidelines.
#
#
# * The homework assignments are executed automatically.
# * Failure to comply with the following instructions will result in a significant penalty.
# * Appeals regarding your failure to read these instructions will be denied.
# * Kindly reminder: the homework assignments contribute 50% of the final grade.
#
#
# ## Read the following instructions carefully:
#
# 1. This Jupyter notebook contains all the step-by-step instructions needed for this exercise.
# 1. Write **efficient**, **vectorized** code whenever possible. Some calculations in this exercise may take several minutes when implemented efficiently, and might take much longer otherwise. Unnecessary loops will result in point deductions.
# 1. You are responsible for the correctness of your code and should add as many tests as you see fit to this jupyter notebook. Tests will not be graded nor checked.
# 1. Complete the required functions in `hw1.py` script only. This exercise is graded automatically, and only the `hw1.py` script is tested.
# 1. You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/), numpy and pandas only. **Do not import anything else.**
# 1. Your code must run without errors. Use at least `numpy` 1.15.4. Any code that cannot run will not be graded.
# 1. Write your own code. Cheating will not be tolerated.
# 1. Submission includes a zip file that contains the hw1.py script as well as this notebook, with your ID as the file name. For example, `hw1_123456789_987654321.zip` if you submitted in pairs and `hw1_123456789.zip` if you submitted the exercise alone.
# Please use only a **zip** file in your submission.
#
# ---
# ---
#
# ## Please sign that you have read and understood the instructions:
#
# 208951111, 322315755
# ---
# ---

# %%
import numpy as np # used for scientific computing
import pandas as pd # used for data analysis and manipulation
import matplotlib.pyplot as plt # used for visualization and plotting
np.random.seed(42) 

# make the notebook automatically reload external python modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Part 1: Data Preprocessing (10 Points)
#
# For the following exercise, we will use a dataset containing housing prices in King County, USA. The dataset contains 5,000 observations with 18 features and a single target value - the house price.
#
# First, we will read and explore the data using pandas and the `.read_csv` method. Pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %%
# Read comma separated data
df = pd.read_csv('data.csv')
# df stands for dataframe, which is the default format for datasets in pandas

# %% [markdown]
# ### Data Exploration
# A good practice in any data-oriented project is to first try and understand the data. Fortunately, pandas is built for that purpose. Start by looking at the top of the dataset using the `df.head()` command. This will be the first indication that you read your data properly, and that the headers are correct. Next, you can use `df.describe()` to show statistics on the data and check for trends and irregularities.

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  yr_built  \
# 0      5650     1.0           0     0          3      7        1180      1955
# 1      7242     2.0           0     0          3      7        2170      1951
# 2     10000     1.0           0     0          3      6         770      1933
# 3      5000     1.0           0     0          5      7        1050      1965
# 4      8080     1.0           0     0          3      8        1680      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
df.describe()
# Out:
#                  id         price   bedrooms    bathrooms   sqft_living  \
# count  5.000000e+03  5.000000e+03  5000.0000  5000.000000   5000.000000
# mean   4.630823e+09  5.394699e+05     3.3714     2.062150   2061.036800
# std    2.870890e+09  3.873115e+05     0.9104     0.773592    923.727509
# min    1.000102e+06  7.500000e+04     0.0000     0.000000    380.000000
# 25%    2.154075e+09  3.179062e+05     3.0000     1.500000   1410.000000
# 50%    4.022900e+09  4.490000e+05     3.0000     2.000000   1890.000000
# 75%    7.345078e+09  6.500000e+05     4.0000     2.500000   2500.000000
# max    9.842300e+09  7.060000e+06     9.0000     6.750000  10040.000000
#
#            sqft_lot       floors   waterfront         view    condition  \
# count  5.000000e+03  5000.000000  5000.000000  5000.000000  5000.000000
# mean   1.615893e+04     1.432600     0.009400     0.243000     3.455000
# std    4.600220e+04     0.510793     0.096506     0.774643     0.677692
# min    6.090000e+02     1.000000     0.000000     0.000000     1.000000
# 25%    5.400000e+03     1.000000     0.000000     0.000000     3.000000
# 50%    7.875000e+03     1.000000     0.000000     0.000000     3.000000
# 75%    1.123400e+04     2.000000     0.000000     0.000000     4.000000
# max    1.651359e+06     3.500000     1.000000     4.000000     5.000000
#
#              grade   sqft_above     yr_built  yr_renovated       zipcode  \
# count  5000.000000  5000.000000  5000.000000   5000.000000   5000.000000
# mean      7.595200  1753.151000  1966.660800     95.052800  98078.812600
# std       1.166537   818.390844    28.286855    425.234932     54.126332
# min       3.000000   380.000000  1900.000000      0.000000  98001.000000
# 25%       7.000000  1190.000000  1949.000000      0.000000  98033.000000
# 50%       7.000000  1530.000000  1968.000000      0.000000  98070.000000
# 75%       8.000000  2130.000000  1990.000000      0.000000  98118.000000
# max      13.000000  7680.000000  2015.000000   2015.000000  98199.000000
#
#                lat         long  sqft_living15     sqft_lot15
# count  5000.000000  5000.000000     5000.00000    5000.000000
# mean     47.559312  -122.215864     1976.84520   13451.164600
# std       0.139521     0.141807      674.73601   26514.749009
# min      47.155900  -122.514000      620.00000     660.000000
# 25%      47.463675  -122.329000     1490.00000    5391.500000
# 50%      47.572850  -122.235000     1820.00000    7800.000000
# 75%      47.679200  -122.129000     2340.00000   10469.250000
# max      47.777600  -121.315000     5790.00000  434728.000000

# %% [markdown]
# We will start with one variable linear regression by extracting the target column and the `sqft_living` variable from the dataset. We use pandas and select both columns as separate variables and transform them into a numpy array.

# %%
X = df['sqft_living'].values
y = df['price'].values

# %% [markdown]
# ## Preprocessing
#
# As the number of features grows, calculating gradients gets computationally expensive. We can speed this up by normalizing the input data to ensure all values are within the same range. This is especially important for datasets with high standard deviations or differences in the ranges of the attributes. Use [mean normalization](https://en.wikipedia.org/wiki/Feature_scaling) for the fearures (`X`) and the true labels (`y`).
#
# Your implementation should not contain loops.
#
# ---
# Open `hw1.py` and complete the function `preprocess`. (5 points)

# %%
from hw1 import preprocess

X, y = preprocess(X, y)
X.shape, y.shape
# Out:
# ((5000,), (5000,))

# %% [markdown]
# We will split the data into two datasets:
# 1. The training dataset will contain 80% of the data and will always be used for model training.
# 2. The validation dataset will contain the remaining 20% of the data and will be used for model evaluation. For example, we will pick the best alpha and the best features using the validation dataset, while still training the model using the training dataset.

# %%
# training and validation split
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train], X[idx_val]
y_train, y_val = y[idx_train], y[idx_val]

# %% [markdown]
# ## Data Visualization
# Another useful tool is data visualization. Since this problem has only two parameters, it is possible to create a two-dimensional scatter plot to visualize the data. Note that many real-world datasets are highly dimensional and cannot be visualized naively. We will be using `matplotlib` for all data visualization purposes since it offers a wide range of visualization tools and is easy to use.

# %%
plt.plot(X_train, y_train, 'ro', ms=1, mec='k') # the parameters control the size, shape and color of the scatter plot
plt.ylabel('Price in USD')
plt.xlabel('sq.ft')
plt.show()

# %% [markdown]
# ## Bias Trick
#
# Make sure that `X` takes into consideration the bias $\theta_0$ in the linear model. Hint, recall that the predications of our linear model are of the form:
#
# $$
# \hat{y} = h_\theta(x) = \theta^T x = \theta_0 + \theta_1 x_1
# $$
#
# Add columns of ones as the zeroth column of the features (do this for both the training and validation sets).
#
# ---
# Open `hw1.py` and complete the function `apply_bias_trick`. (5 points)

# %%
from hw1 import apply_bias_trick

X_train = apply_bias_trick(X_train)
X_val = apply_bias_trick(X_val)

X_train.shape, X_val.shape
# Out:
# ((4000, 2), (1000, 2))

# %% [markdown]
# ## Part 2: Single Variable Linear Regression (60 Points)
# Simple linear regression is a linear regression model with a single explanatory varaible and a single target value.
#
# $$
# \hat{y} = h_\theta(x) = \theta^T x = \theta_0 + \theta_1 x_1
# $$
#
# ## Gradient Descent
#
# Our task is to find the best possible linear line that explains all the points in our dataset. We start by guessing initial values for the linear regression parameters $\theta$ and updating the values using gradient descent.
#
# The objective of linear regression is to minimize the cost function $J$:
#
# $$
# J(\theta) = \frac{1}{2m} \sum_{i=1}^{m}(h_\theta(x^{(i)})-y^{(i)})^2
# $$
#
# where the hypothesis (model) $h_\theta(x)$ is given by a **linear** model:
#
# $$
# h_\theta(x) = \theta^T x = \theta_0 + \theta_1 x_1
# $$
#
# $\theta_j$ are parameters of your model. and by changing those values accordingly you will be able to lower the cost function $J(\theta)$. One way to accopmlish this is to use gradient descent:
#
# $$
# \theta_j = \theta_j - \alpha \frac{1}{m} \sum_{i=1}^m (h_\theta(x^{(i)})-y^{(i)})x_j^{(i)}
# $$
#
# In linear regresion, we know that with each step of gradient descent, the parameters $\theta_j$ get closer to the optimal values that will achieve the lowest cost $J(\theta)$.
#
# ---
#
# Open `hw1.py` and complete the function `compute_cost`. (10 points)

# %%
from hw1 import compute_cost
theta = np.array([-1, 2])
J = compute_cost(X_train, y_train, theta)

# %% [markdown]
# Open `hw1.py` and complete the function `gradient_descent`. (30 points)

# %%
from hw1 import gradient_descent

np.random.seed(42)
theta = np.random.random(size=2)
iterations = 40000
alpha = 0.1
theta, J_history = gradient_descent(X_train ,y_train, theta, alpha, iterations)

# %% [markdown]
# You can evaluate the learning process by monitoring the loss as training progress. In the following graph, we visualize the loss as a function of the iterations. This is possible since we are saving the loss value at every iteration in the `J_history` array. This visualization might help you find problems with your code. Notice that since the network converges quickly, we are using logarithmic scale for the number of iterations.

# %%
plt.plot(np.arange(iterations), J_history)
plt.xscale('log')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations')
plt.show()

# %% [markdown]
# The pseudo inverse solution is a direct approach to finding the best-fitting parameters of the linear model. In your implementation, **do not use `np.linalg.pinv`**. Instead, use only direct matrix multiplication as you saw in class (you can calculate the inverse of a matrix using `np.linalg.inv`).
#
# ---
# Open `hw1.py` and complete the function `compute_pinv`. (10 points)

# %%
from hw1 import compute_pinv

# %%
theta_pinv = compute_pinv(X_train ,y_train)
J_pinv = compute_cost(X_train, y_train, theta_pinv)

# %% [markdown]
# We can add the loss value for the theta calculated using the psuedo-inverse to our graph. This is another sanity check as the loss of our model should converge to the psuedo-inverse loss.

# %%
plt.plot(np.arange(len(J_history)), J_history)
plt.xscale('log')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations')
plt.hlines(y = J_pinv, xmin = 0, xmax = len(J_history), color='r',
           linewidth = 1, linestyle = 'dashed')
plt.show()

# %% [markdown]
# We can use a better approach for the implementation of `gradient_descent`. Instead of performing 40,000 iterations, we wish to stop when the improvement of the loss value is smaller than `1e-8` from one iteration to the next.
#
# The learning rate is another factor that determines the performance of our model in terms of speed and accuracy. Complete the function `find_best_alpha`. Make sure you use the training dataset to learn the parameters (thetas) and use those parameters with the validation dataset to compute the cost.
#
# **After implementing `efficient_gradient_descent` and finding the best alpha value, use them for the rest of the exercise.**
#
# ---
# Open `hw1.py` and complete the function `efficient_gradient_descent` and `find_best_alpha`. (5 points each)

# %%
from hw1 import efficient_gradient_descent, find_best_alpha

# %%
alpha_dict = find_best_alpha(X_train, y_train, X_val, y_val, iterations)
# Out:
# Trying alpha: 1e-05
# Trying alpha: 3e-05
# Trying alpha: 0.0001
# Trying alpha: 0.0003
# Trying alpha: 0.001
# Trying alpha: 0.003
# Trying alpha: 0.01
# Trying alpha: 0.03
# Trying alpha: 0.1
# Trying alpha: 0.3
# Trying alpha: 1
# Trying alpha: 2
# Trying alpha: 3

# %% [markdown]
# We can now obtain the best learning rate from the dictionary `alpha_dict` in a single line.

# %%
best_alpha = min(alpha_dict, key=alpha_dict.get)

# %%
best_alpha = 1

# %% [markdown]
# The following code gets the best three alpha values you just calculated and provides a graph with three lines indicating the training loss as a function of iterations. Use it as a test for your implementation. You can change this code as you see fit.

# %%
top_3_alphas = sorted([(value, key) for key, value in alpha_dict.items()], reverse=False)[:3]
top_3_alphas = [x[1] for x in top_3_alphas]

histories = []
for alpha in top_3_alphas:
    params = np.random.random(size=2)
    _, J_history = gradient_descent(X_train ,y_train, params, alpha, iterations)
    histories.append(J_history)

for i, (alpha, color) in enumerate(zip(top_3_alphas, ['b','g','r'])):
    plt.plot(np.arange(iterations), histories[i], color, label='alpha='+str(alpha))

plt.xscale('log')
plt.ylim(0, 0.005)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations')
plt.legend()
plt.show()

# %% [markdown]
# This is yet another check. This function plots the regression lines of your model and the model based on the pseudoinverse calculation. Both models should exhibit the same trend through the data.

# %%
plt.figure(figsize=(7, 7))
plt.plot(X_train[:,1], y_train, 'ro', ms=1, mec='k')
plt.ylabel('Price in USD')
plt.xlabel('sq.ft')
plt.plot(X_train[:, 1], np.dot(X_train, theta), 'o')
plt.plot(X_train[:, 1], np.dot(X_train, theta_pinv), '-')

plt.legend(['Training data', 'Linear regression', 'Best theta']);

# %% [markdown]
# ## Part 2: Multivariate Linear Regression
#
# In most cases, you will deal with datasets that have more than one feature. It can be as little as two features and up to thousands of features. In those cases, we use a multivariate linear regression model. The regression equation is almost the same as the simple linear regression equation:
#
# $$
# \hat{y} = h_\theta(\vec{x}) = \theta^T \vec{x} = \theta_0 + \theta_1 x_1 + ... + \theta_n x_n
# $$
#
#
# If you wrote proper vectorized code, this part should be trivial and work without changes. If this is not the case, you should go back and edit your functions such that they support both multivariate and single variable regression. **Your code should not check the dimensionality of the input before running**.

# %%
# Read comma separated data
df = pd.read_csv('data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  yr_built  \
# 0      5650     1.0           0     0          3      7        1180      1955
# 1      7242     2.0           0     0          3      7        2170      1951
# 2     10000     1.0           0     0          3      6         770      1933
# 3      5000     1.0           0     0          5      7        1050      1965
# 4      8080     1.0           0     0          3      8        1680      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# ## Preprocessing
#
# Like in the single variable case, we need to create a numpy array from the dataframe. Before doing so, we should notice that some of the features are clearly irrelevant so we will go ahead and drop them.

# %%
X = df.drop(columns=['price', 'id', 'date']).values
y = df['price'].values

# %% [markdown]
# Use the same `preprocess` function you implemented previously. Notice that proper vectorized implementation should work regardless of the dimensionality of the input. You might want to check that your code in the previous parts still works.

# %%
# preprocessing
X, y = preprocess(X, y)

# %%
# training and validation split 
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train,:], X[idx_val,:]
y_train, y_val = y[idx_train], y[idx_val]

# %% [markdown]
# Using 3D visualization, we can still observe trends in the data. Visualizing additional dimensions requires advanced techniques we will learn later in the course.

# %%
# %matplotlib inline
import mpl_toolkits.mplot3d.axes3d as p3
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')
xx = X_train[:, 1][:1000]
yy = X_train[:, 2][:1000]
zz = y_train[:1000]
ax.scatter(xx, yy, zz, marker='o')
ax.set_xlabel('bathrooms')
ax.set_ylabel('sqft_living')
ax.set_zlabel('price')
plt.show()

# %% [markdown]
# Make sure the functions `apply_bias_trick`, `compute_cost`, `gradient_descent`, `efficient_gradient_descent` and `compute_pinv` work on the multi-dimensional dataset. If you make any changes, make sure your code still works on the single variable regression model.

# %%
# bias trick
X_train = apply_bias_trick(X_train)
X_val = apply_bias_trick(X_val)

X_train.shape, X_val.shape
# Out:
# ((4000, 18), (1000, 18))

# %%
# calculating the cost
shape = X_train.shape[1]
theta = np.ones(shape)
J = compute_cost(X_train, y_train, theta)

# %%
# running the efficient version of gradient descent
np.random.seed(42)
shape = X_train.shape[1] 
theta = np.random.random(shape)
theta, J_history = efficient_gradient_descent(X_train ,y_train, theta, best_alpha, iterations)

# %%
# calculating the pseudoinverse
theta_pinv = compute_pinv(X_train ,y_train)
J_pinv = compute_cost(X_train, y_train, theta_pinv)

# %% [markdown]
# We can use visualization to make sure the code works well. Notice we use logarithmic scale for the number of iterations, since gradient descent converges after ~500 iterations.

# %%
plt.plot(np.arange(len(J_history)), J_history)
plt.xscale('log')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations - multivariate linear regression')
plt.hlines(y = J_pinv, xmin = 0, xmax = len(J_history), color='r',
           linewidth = 1, linestyle = 'dashed')
plt.show()

# %% [markdown]
# ## Part 3: Forward feature selection (15 points)
#
# Adding additional features to our regression model makes it more complicated but does not necessarily improves performance.
#
# Forward feature selection is a greedy, iterative algorithm used to select the most relevant features for a predictive model. The objective of this algorithm is to improve the model's performance by identifying and using only the most relevant features, potentially reducing overfitting, improving accuracy, and reducing computational cost.
#
# Implement forward feature selection using the following guidelines:
# 1. Start with an empty set of selected features.
# 1. For each feature not yet in the selected set, do the following:
#     1. Add the feature to the selected set temporarily.
#     1. Train a model using the current set of selected features and evaluate its performance by calculating the cost or error on a validation set.
#     1. Remove the temporarily added feature from the selected set.
# 1. Choose the feature that resulted in the best model performance and permanently add it to the selected set.
# 1. Repeat steps 2-3 until you have 5 features (not including the bias).
#
# ---
# Open `hw1.py` and complete the function `forward_feature_selection`.
#
# **Note that you should use the inputs as provided in the next cell and don't forget to use the bias trick inside `forward_feature_selection`**.

# %%
df = pd.read_csv('data.csv')
feature_names = df.drop(columns=['price', 'id', 'date']).columns.values
X = df.drop(columns=['price', 'id', 'date']).values
y = df['price'].values

# %%
df = pd.read_csv('data.csv')
feature_names = df.drop(columns=['price', 'id', 'date']).columns.values
X = df.drop(columns=['price', 'id', 'date']).values
y = df['price'].values

# preprocessing
X, y = preprocess(X, y)

# training and validation split
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train,:], X[idx_val,:]
y_train, y_val = y[idx_train], y[idx_val]

# %%
from hw1 import forward_feature_selection

# %%
ffs = forward_feature_selection(X_train, y_train, X_val, y_val, best_alpha, iterations)
for feature in ffs:
    print(feature_names[feature])
# Out:
# Considering feature: 0
# Considering feature set: [0]
# Considering feature: 1
# Considering feature set: [1]
# found new min cost for 1 features:
#                                 old min_cost 0.0012882907771249142, new min_cost: 0.0009867979911248473. diff = 0.0003014927860000669
#                                 old selected_features [0], new selected_features: [1]
# Considering feature: 2
# Considering feature set: [2]
# found new min cost for 1 features:
#                                 old min_cost 0.0009867979911248473, new min_cost: 0.0007074118603530315. diff = 0.00027938613077181586
#                                 old selected_features [1], new selected_features: [2]
# Considering feature: 3
# Considering feature set: [3]
# Considering feature: 4
# Considering feature set: [4]
# Considering feature: 5
# Considering feature set: [5]
# Considering feature: 6
# Considering feature set: [6]
# Considering feature: 7
# Considering feature set: [7]
# Considering feature: 8
# Considering feature set: [8]
# Considering feature: 9
# Considering feature set: [9]
# Considering feature: 10
# Considering feature set: [10]
# Considering feature: 11
# Considering feature set: [11]
# Considering feature: 12
# Considering feature set: [12]
# Considering feature: 13
# Considering feature set: [13]
# Considering feature: 14
# Considering feature set: [14]
# Considering feature: 15
# Considering feature set: [15]
# Considering feature: 16
# Considering feature set: [16]
# Considering feature: 0
# Considering feature set: [2, 0]
# Considering feature: 1
# Considering feature set: [2, 1]
# Considering feature: 3
# Considering feature set: [2, 3]
# Considering feature: 4
# Considering feature set: [2, 4]
# Considering feature: 5
# Considering feature set: [2, 5]
# found new min cost for 2 features:
#                                 old min_cost 0.000683487624234418, new min_cost: 0.0006256052784356618. diff = 5.788234579875626e-05
#                                 old selected_features [2, 0], new selected_features: [2, 5]
# Considering feature: 6
# Considering feature set: [2, 6]
# Considering feature: 7
# Considering feature set: [2, 7]
# Considering feature: 8
# Considering feature set: [2, 8]
# Considering feature: 9
# Considering feature set: [2, 9]
# Considering feature: 10
# Considering feature set: [2, 10]
# Considering feature: 11
# Considering feature set: [2, 11]
# Considering feature: 12
# Considering feature set: [2, 12]
# Considering feature: 13
# Considering feature set: [2, 13]
# found new min cost for 2 features:
#                                 old min_cost 0.0006256052784356618, new min_cost: 0.0006122604576554209. diff = 1.3344820780240851e-05
#                                 old selected_features [2, 5], new selected_features: [2, 13]
# Considering feature: 14
# Considering feature set: [2, 14]
# Considering feature: 15
# Considering feature set: [2, 15]
# Considering feature: 16
# Considering feature set: [2, 16]
# Considering feature: 0
# Considering feature set: [2, 13, 0]
# Considering feature: 1
# Considering feature set: [2, 13, 1]
# Considering feature: 3
# Considering feature set: [2, 13, 3]
# Considering feature: 4
# Considering feature set: [2, 13, 4]
# Considering feature: 5
# Considering feature set: [2, 13, 5]
# found new min cost for 3 features:
#                                 old min_cost 0.0005931767252151337, new min_cost: 0.000524760446134669. diff = 6.841627908046465e-05
#                                 old selected_features [2, 13, 0], new selected_features: [2, 13, 5]
# Considering feature: 6
# Considering feature set: [2, 13, 6]
# Considering feature: 7
# Considering feature set: [2, 13, 7]
# Considering feature: 8
# Considering feature set: [2, 13, 8]
# Considering feature: 9
# Considering feature set: [2, 13, 9]
# Considering feature: 10
# Considering feature set: [2, 13, 10]
# Considering feature: 11
# Considering feature set: [2, 13, 11]
# Considering feature: 12
# Considering feature set: [2, 13, 12]
# Considering feature: 14
# Considering feature set: [2, 13, 14]
# Considering feature: 15
# Considering feature set: [2, 13, 15]
# Considering feature: 16
# Considering feature set: [2, 13, 16]
# Considering feature: 0
# Considering feature set: [2, 13, 5, 0]
# Considering feature: 1
# Considering feature set: [2, 13, 5, 1]
# Considering feature: 3
# Considering feature set: [2, 13, 5, 3]
# Considering feature: 4
# Considering feature set: [2, 13, 5, 4]
# Considering feature: 6
# Considering feature set: [2, 13, 5, 6]
# found new min cost for 4 features:
#                                 old min_cost 0.0005141215043463765, new min_cost: 0.0005112132600958377. diff = 2.9082442505387737e-06
#                                 old selected_features [2, 13, 5, 0], new selected_features: [2, 13, 5, 6]
# Considering feature: 7
# Considering feature set: [2, 13, 5, 7]
# Considering feature: 8
# Considering feature set: [2, 13, 5, 8]
# found new min cost for 4 features:
#                                 old min_cost 0.0005112132600958377, new min_cost: 0.0004951532793586658. diff = 1.6059980737171938e-05
#                                 old selected_features [2, 13, 5, 6], new selected_features: [2, 13, 5, 8]
# Considering feature: 9
# Considering feature set: [2, 13, 5, 9]
# Considering feature: 10
# Considering feature set: [2, 13, 5, 10]
# Considering feature: 11
# Considering feature set: [2, 13, 5, 11]
# Considering feature: 12
# Considering feature set: [2, 13, 5, 12]
# Considering feature: 14
# Considering feature set: [2, 13, 5, 14]
# Considering feature: 15
# Considering feature set: [2, 13, 5, 15]
# Considering feature: 16
# Considering feature set: [2, 13, 5, 16]
# Considering feature: 0
# Considering feature set: [2, 13, 5, 8, 0]
# Considering feature: 1
# Considering feature set: [2, 13, 5, 8, 1]
# Considering feature: 3
# Considering feature set: [2, 13, 5, 8, 3]
# Considering feature: 4
# Considering feature set: [2, 13, 5, 8, 4]
# Considering feature: 6
# Considering feature set: [2, 13, 5, 8, 6]
# found new min cost for 5 features:
#                                 old min_cost 0.0004889191627611292, new min_cost: 0.0004778614866592482. diff = 1.1057676101880996e-05
#                                 old selected_features [2, 13, 5, 8, 0], new selected_features: [2, 13, 5, 8, 6]
# Considering feature: 7
# Considering feature set: [2, 13, 5, 8, 7]
# Considering feature: 9
# Considering feature set: [2, 13, 5, 8, 9]
# Considering feature: 10
# Considering feature set: [2, 13, 5, 8, 10]
# found new min cost for 5 features:
#                                 old min_cost 0.0004778614866592482, new min_cost: 0.0004482036415436827. diff = 2.965784511556552e-05
#                                 old selected_features [2, 13, 5, 8, 6], new selected_features: [2, 13, 5, 8, 10]
# Considering feature: 11
# Considering feature set: [2, 13, 5, 8, 11]
# Considering feature: 12
# Considering feature set: [2, 13, 5, 8, 12]
# Considering feature: 14
# Considering feature set: [2, 13, 5, 8, 14]
# Considering feature: 15
# Considering feature set: [2, 13, 5, 8, 15]
# Considering feature: 16
# Considering feature set: [2, 13, 5, 8, 16]
# sqft_living
# lat
# waterfront
# grade
# yr_built

# %% [markdown]
# ## Part 4: Polynomial regression (15 points)
#
# Implement a function to create polynomial features up to a degree of 2 for given dataset. The function should take a pandas DataFrame as input and should return a new DataFrame with all possible square features, including the original features. When you create the new dataframe, make sure the feature names also represent the transformation performed. For example: `sqft_lot`, `yr_built^2`, `bedrooms*bathrooms`, ...
#
# After you obtain the polynomial dataframe, use forward feature selection and print the 5 best features.
#
# Open `hw1.py` and complete the function `create_square_features`.

# %%
from hw1 import create_square_features

# %%
df = pd.read_csv('data.csv')

y = df['price'].values
df = df.drop(columns=['price', 'id', 'date'])
df = df.astype('float64')
df_poly = create_square_features(df)
X = df_poly.values
X.shape, y.shape
# Out:
# ((5000, 170), (5000,))

# %%
# preprocessing
X, y = preprocess(X, y)

# %%
# training and validation split
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train,:], X[idx_val,:]
y_train, y_val = y[idx_train], y[idx_val]

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((4000, 170), (1000, 170), (4000,), (1000,))

# %%
feature_names = df_poly.columns.values

# %%
ffs = forward_feature_selection(X_train, y_train, X_val, y_val, best_alpha, iterations)
# Out:
# Considering feature: 0
# Considering feature set: [0]
# Considering feature: 1
# Considering feature set: [1]
# found new min cost for 1 features:
#                                 old min_cost 0.0012882907771249142, new min_cost: 0.0009867979911248473. diff = 0.0003014927860000669
#                                 old selected_features [0], new selected_features: [1]
# Considering feature: 2
# Considering feature set: [2]
# found new min cost for 1 features:
#                                 old min_cost 0.0009867979911248473, new min_cost: 0.0007074118603530315. diff = 0.00027938613077181586
#                                 old selected_features [1], new selected_features: [2]
# Considering feature: 3
# Considering feature set: [3]
# Considering feature: 4
# Considering feature set: [4]
# Considering feature: 5
# Considering feature set: [5]
# Considering feature: 6
# Considering feature set: [6]
# Considering feature: 7
# Considering feature set: [7]
# Considering feature: 8
# Considering feature set: [8]
# Considering feature: 9
# Considering feature set: [9]
# Considering feature: 10
# Considering feature set: [10]
# Considering feature: 11
# Considering feature set: [11]
# Considering feature: 12
# Considering feature set: [12]
# Considering feature: 13
# Considering feature set: [13]
# Considering feature: 14
# Considering feature set: [14]
# Considering feature: 15
# Considering feature set: [15]
# Considering feature: 16
# Considering feature set: [16]
# Considering feature: 17
# Considering feature set: [17]
# Considering feature: 18
# Considering feature set: [18]
# Considering feature: 19
# Considering feature set: [19]
# Considering feature: 20
# Considering feature set: [20]
# Considering feature: 21
# Considering feature set: [21]
# Considering feature: 22
# Considering feature set: [22]
# Considering feature: 23
# Considering feature set: [23]
# Considering feature: 24
# Considering feature set: [24]
# Considering feature: 25
# Considering feature set: [25]
# Considering feature: 26
# Considering feature set: [26]
# Considering feature: 27
# Considering feature set: [27]
# Considering feature: 28
# Considering feature set: [28]
# Considering feature: 29
# Considering feature set: [29]
# Considering feature: 30
# Considering feature set: [30]
# Considering feature: 31
# Considering feature set: [31]
# Considering feature: 32
# Considering feature set: [32]
# Considering feature: 33
# Considering feature set: [33]
# Considering feature: 34
# Considering feature set: [34]
# Considering feature: 35
# Considering feature set: [35]
# found new min cost for 1 features:
#                                 old min_cost 0.0007074118603530315, new min_cost: 0.0006640909309379242. diff = 4.332092941510728e-05
#                                 old selected_features [2], new selected_features: [35]
# Considering feature: 36
# Considering feature set: [36]
# Considering feature: 37
# Considering feature set: [37]
# Considering feature: 38
# Considering feature set: [38]
# Considering feature: 39
# Considering feature set: [39]
# Considering feature: 40
# Considering feature set: [40]
# Considering feature: 41
# Considering feature set: [41]
# Considering feature: 42
# Considering feature set: [42]
# Considering feature: 43
# Considering feature set: [43]
# Considering feature: 44
# Considering feature set: [44]
# Considering feature: 45
# Considering feature set: [45]
# Considering feature: 46
# Considering feature set: [46]
# Considering feature: 47
# Considering feature set: [47]
# Considering feature: 48
# Considering feature set: [48]
# Considering feature: 49
# Considering feature set: [49]
# Considering feature: 50
# Considering feature set: [50]
# found new min cost for 1 features:
#                                 old min_cost 0.0006640909309379242, new min_cost: 0.0006326912589005176. diff = 3.1399672037406615e-05
#                                 old selected_features [35], new selected_features: [50]
# Considering feature: 51
# Considering feature set: [51]
# Considering feature: 52
# Considering feature set: [52]
# Considering feature: 53
# Considering feature set: [53]
# Considering feature: 54
# Considering feature set: [54]
# Considering feature: 55
# Considering feature set: [55]
# Considering feature: 56
# Considering feature set: [56]
# found new min cost for 1 features:
#                                 old min_cost 0.0006326912589005176, new min_cost: 0.0006006105485803266. diff = 3.208071032019099e-05
#                                 old selected_features [50], new selected_features: [56]
# Considering feature: 57
# Considering feature set: [57]
# Considering feature: 58
# Considering feature set: [58]
# Considering feature: 59
# Considering feature set: [59]
# Considering feature: 60
# Considering feature set: [60]
# Considering feature: 61
# Considering feature set: [61]
# Considering feature: 62
# Considering feature set: [62]
# Considering feature: 63
# Considering feature set: [63]
# Considering feature: 64
# Considering feature set: [64]
# Considering feature: 65
# Considering feature set: [65]
# Considering feature: 66
# Considering feature set: [66]
# Considering feature: 67
# Considering feature set: [67]
# Considering feature: 68
# Considering feature set: [68]
# Considering feature: 69
# Considering feature set: [69]
# Considering feature: 70
# Considering feature set: [70]
# Considering feature: 71
# Considering feature set: [71]
# Considering feature: 72
# Considering feature set: [72]
# Considering feature: 73
# Considering feature set: [73]
# Considering feature: 74
# Considering feature set: [74]
# Considering feature: 75
# Considering feature set: [75]
# Considering feature: 76
# Considering feature set: [76]
# Considering feature: 77
# Considering feature set: [77]
# Considering feature: 78
# Considering feature set: [78]
# Considering feature: 79
# Considering feature set: [79]
# Considering feature: 80
# Considering feature set: [80]
# Considering feature: 81
# Considering feature set: [81]
# Considering feature: 82
# Considering feature set: [82]
# Considering feature: 83
# Considering feature set: [83]
# Considering feature: 84
# Considering feature set: [84]
# Considering feature: 85
# Considering feature set: [85]
# Considering feature: 86
# Considering feature set: [86]
# Considering feature: 87
# Considering feature set: [87]
# Considering feature: 88
# Considering feature set: [88]
# Considering feature: 89
# Considering feature set: [89]
# Considering feature: 90
# Considering feature set: [90]
# Considering feature: 91
# Considering feature set: [91]
# Considering feature: 92
# Considering feature set: [92]
# Considering feature: 93
# Considering feature set: [93]
# Considering feature: 94
# Considering feature set: [94]
# Considering feature: 95
# Considering feature set: [95]
# Considering feature: 96
# Considering feature set: [96]
# Considering feature: 97
# Considering feature set: [97]
# Considering feature: 98
# Considering feature set: [98]
# Considering feature: 99
# Considering feature set: [99]
# Considering feature: 100
# Considering feature set: [100]
# Considering feature: 101
# Considering feature set: [101]
# Considering feature: 102
# Considering feature set: [102]
# Considering feature: 103
# Considering feature set: [103]
# Considering feature: 104
# Considering feature set: [104]
# Considering feature: 105
# Considering feature set: [105]
# Considering feature: 106
# Considering feature set: [106]
# Considering feature: 107
# Considering feature set: [107]
# Considering feature: 108
# Considering feature set: [108]
# Considering feature: 109
# Considering feature set: [109]
# Considering feature: 110
# Considering feature set: [110]
# Considering feature: 111
# Considering feature set: [111]
# Considering feature: 112
# Considering feature set: [112]
# Considering feature: 113
# Considering feature set: [113]
# Considering feature: 114
# Considering feature set: [114]
# Considering feature: 115
# Considering feature set: [115]
# Considering feature: 116
# Considering feature set: [116]
# Considering feature: 117
# Considering feature set: [117]
# Considering feature: 118
# Considering feature set: [118]
# Considering feature: 119
# Considering feature set: [119]
# Considering feature: 120
# Considering feature set: [120]
# Considering feature: 121
# Considering feature set: [121]
# Considering feature: 122
# Considering feature set: [122]
# Considering feature: 123
# Considering feature set: [123]
# Considering feature: 124
# Considering feature set: [124]
# Considering feature: 125
# Considering feature set: [125]
# Considering feature: 126
# Considering feature set: [126]
# Considering feature: 127
# Considering feature set: [127]
# Considering feature: 128
# Considering feature set: [128]
# Considering feature: 129
# Considering feature set: [129]
# Considering feature: 130
# Considering feature set: [130]
# Considering feature: 131
# Considering feature set: [131]
# Considering feature: 132
# Considering feature set: [132]
# Considering feature: 133
# Considering feature set: [133]
# Considering feature: 134
# Considering feature set: [134]
# Considering feature: 135
# Considering feature set: [135]
# Considering feature: 136
# Considering feature set: [136]
# Considering feature: 137
# Considering feature set: [137]
# Considering feature: 138
# Considering feature set: [138]
# Considering feature: 139
# Considering feature set: [139]
# Considering feature: 140
# Considering feature set: [140]
# Considering feature: 141
# Considering feature set: [141]
# Considering feature: 142
# Considering feature set: [142]
# Considering feature: 143
# Considering feature set: [143]
# Considering feature: 144
# Considering feature set: [144]
# Considering feature: 145
# Considering feature set: [145]
# Considering feature: 146
# Considering feature set: [146]
# Considering feature: 147
# Considering feature set: [147]
# Considering feature: 148
# Considering feature set: [148]
# Considering feature: 149
# Considering feature set: [149]
# Considering feature: 150
# Considering feature set: [150]
# Considering feature: 151
# Considering feature set: [151]
# Considering feature: 152
# Considering feature set: [152]
# Considering feature: 153
# Considering feature set: [153]
# Considering feature: 154
# Considering feature set: [154]
# Considering feature: 155
# Considering feature set: [155]
# Considering feature: 156
# Considering feature set: [156]
# Considering feature: 157
# Considering feature set: [157]
# Considering feature: 158
# Considering feature set: [158]
# Considering feature: 159
# Considering feature set: [159]
# Considering feature: 160
# Considering feature set: [160]
# Considering feature: 161
# Considering feature set: [161]
# Considering feature: 162
# Considering feature set: [162]
# Considering feature: 163
# Considering feature set: [163]
# Considering feature: 164
# Considering feature set: [164]
# Considering feature: 165
# Considering feature set: [165]
# Considering feature: 166
# Considering feature set: [166]
# Considering feature: 167
# Considering feature set: [167]
# Considering feature: 168
# Considering feature set: [168]
# Considering feature: 169
# Considering feature set: [169]
# Considering feature: 0
# Considering feature set: [56, 0]
# Considering feature: 1
# Considering feature set: [56, 1]
# Considering feature: 2
# Considering feature set: [56, 2]
# found new min cost for 2 features:
#                                 old min_cost 0.0005837662523706644, new min_cost: 0.0005835977789047609. diff = 1.6847346590346222e-07
#                                 old selected_features [56, 0], new selected_features: [56, 2]
# Considering feature: 3
# Considering feature set: [56, 3]
# Considering feature: 4
# Considering feature set: [56, 4]
# Considering feature: 5
# Considering feature set: [56, 5]
# found new min cost for 2 features:
#                                 old min_cost 0.0005835977789047609, new min_cost: 0.0005372576706670581. diff = 4.634010823770284e-05
#                                 old selected_features [56, 2], new selected_features: [56, 5]
# Considering feature: 6
# Considering feature set: [56, 6]
# Considering feature: 7
# Considering feature set: [56, 7]
# Considering feature: 8
# Considering feature set: [56, 8]
# Considering feature: 9
# Considering feature set: [56, 9]
# Considering feature: 10
# Considering feature set: [56, 10]
# found new min cost for 2 features:
#                                 old min_cost 0.0005372576706670581, new min_cost: 0.00052745102506089. diff = 9.806645606168143e-06
#                                 old selected_features [56, 5], new selected_features: [56, 10]
# Considering feature: 11
# Considering feature set: [56, 11]
# Considering feature: 12
# Considering feature set: [56, 12]
# Considering feature: 13
# Considering feature set: [56, 13]
# found new min cost for 2 features:
#                                 old min_cost 0.00052745102506089, new min_cost: 0.0005143350035359798. diff = 1.3116021524910192e-05
#                                 old selected_features [56, 10], new selected_features: [56, 13]
# Considering feature: 14
# Considering feature set: [56, 14]
# Considering feature: 15
# Considering feature set: [56, 15]
# Considering feature: 16
# Considering feature set: [56, 16]
# Considering feature: 17
# Considering feature set: [56, 17]
# Considering feature: 18
# Considering feature set: [56, 18]
# Considering feature: 19
# Considering feature set: [56, 19]
# Considering feature: 20
# Considering feature set: [56, 20]
# Considering feature: 21
# Considering feature set: [56, 21]
# Considering feature: 22
# Considering feature set: [56, 22]
# Considering feature: 23
# Considering feature set: [56, 23]
# Considering feature: 24
# Considering feature set: [56, 24]
# Considering feature: 25
# Considering feature set: [56, 25]
# Considering feature: 26
# Considering feature set: [56, 26]
# Considering feature: 27
# Considering feature set: [56, 27]
# Considering feature: 28
# Considering feature set: [56, 28]
# Considering feature: 29
# Considering feature set: [56, 29]
# Considering feature: 30
# Considering feature set: [56, 30]
# Considering feature: 31
# Considering feature set: [56, 31]
# Considering feature: 32
# Considering feature set: [56, 32]
# Considering feature: 33
# Considering feature set: [56, 33]
# Considering feature: 34
# Considering feature set: [56, 34]
# Considering feature: 35
# Considering feature set: [56, 35]
# Considering feature: 36
# Considering feature set: [56, 36]
# Considering feature: 37
# Considering feature set: [56, 37]
# Considering feature: 38
# Considering feature set: [56, 38]
# Considering feature: 39
# Considering feature set: [56, 39]
# Considering feature: 40
# Considering feature set: [56, 40]
# Considering feature: 41
# Considering feature set: [56, 41]
# Considering feature: 42
# Considering feature set: [56, 42]
# Considering feature: 43
# Considering feature set: [56, 43]
# Considering feature: 44
# Considering feature set: [56, 44]
# Considering feature: 45
# Considering feature set: [56, 45]
# Considering feature: 46
# Considering feature set: [56, 46]
# Considering feature: 47
# Considering feature set: [56, 47]
# Considering feature: 48
# Considering feature set: [56, 48]
# Considering feature: 49
# Considering feature set: [56, 49]
# Considering feature: 50
# Considering feature set: [56, 50]
# Considering feature: 51
# Considering feature set: [56, 51]
# Considering feature: 52
# Considering feature set: [56, 52]
# Considering feature: 53
# Considering feature set: [56, 53]
# Considering feature: 54
# Considering feature set: [56, 54]
# Considering feature: 55
# Considering feature set: [56, 55]
# Considering feature: 57
# Considering feature set: [56, 57]
# Considering feature: 58
# Considering feature set: [56, 58]
# Considering feature: 59
# Considering feature set: [56, 59]
# Considering feature: 60
# Considering feature set: [56, 60]
# Considering feature: 61
# Considering feature set: [56, 61]
# Considering feature: 62
# Considering feature set: [56, 62]
# Considering feature: 63
# Considering feature set: [56, 63]
# Considering feature: 64
# Considering feature set: [56, 64]
# Considering feature: 65
# Considering feature set: [56, 65]
# Considering feature: 66
# Considering feature set: [56, 66]
# Considering feature: 67
# Considering feature set: [56, 67]
# Considering feature: 68
# Considering feature set: [56, 68]
# Considering feature: 69
# Considering feature set: [56, 69]
# Considering feature: 70
# Considering feature set: [56, 70]
# Considering feature: 71
# Considering feature set: [56, 71]
# Considering feature: 72
# Considering feature set: [56, 72]
# Considering feature: 73
# Considering feature set: [56, 73]
# Considering feature: 74
# Considering feature set: [56, 74]
# Considering feature: 75
# Considering feature set: [56, 75]
# Considering feature: 76
# Considering feature set: [56, 76]
# Considering feature: 77
# Considering feature set: [56, 77]
# Considering feature: 78
# Considering feature set: [56, 78]
# Considering feature: 79
# Considering feature set: [56, 79]
# Considering feature: 80
# Considering feature set: [56, 80]
# Considering feature: 81
# Considering feature set: [56, 81]
# Considering feature: 82
# Considering feature set: [56, 82]
# Considering feature: 83
# Considering feature set: [56, 83]
# Considering feature: 84
# Considering feature set: [56, 84]
# Considering feature: 85
# Considering feature set: [56, 85]
# Considering feature: 86
# Considering feature set: [56, 86]
# Considering feature: 87
# Considering feature set: [56, 87]
# Considering feature: 88
# Considering feature set: [56, 88]
# Considering feature: 89
# Considering feature set: [56, 89]
# Considering feature: 90
# Considering feature set: [56, 90]
# Considering feature: 91
# Considering feature set: [56, 91]
# Considering feature: 92
# Considering feature set: [56, 92]
# Considering feature: 93
# Considering feature set: [56, 93]
# Considering feature: 94
# Considering feature set: [56, 94]
# Considering feature: 95
# Considering feature set: [56, 95]
# Considering feature: 96
# Considering feature set: [56, 96]
# Considering feature: 97
# Considering feature set: [56, 97]
# Considering feature: 98
# Considering feature set: [56, 98]
# Considering feature: 99
# Considering feature set: [56, 99]
# Considering feature: 100
# Considering feature set: [56, 100]
# Considering feature: 101
# Considering feature set: [56, 101]
# Considering feature: 102
# Considering feature set: [56, 102]
# Considering feature: 103
# Considering feature set: [56, 103]
# Considering feature: 104
# Considering feature set: [56, 104]
# Considering feature: 105
# Considering feature set: [56, 105]
# Considering feature: 106
# Considering feature set: [56, 106]
# Considering feature: 107
# Considering feature set: [56, 107]
# Considering feature: 108
# Considering feature set: [56, 108]
# Considering feature: 109
# Considering feature set: [56, 109]
# Considering feature: 110
# Considering feature set: [56, 110]
# Considering feature: 111
# Considering feature set: [56, 111]
# Considering feature: 112
# Considering feature set: [56, 112]
# Considering feature: 113
# Considering feature set: [56, 113]
# Considering feature: 114
# Considering feature set: [56, 114]
# Considering feature: 115
# Considering feature set: [56, 115]
# Considering feature: 116
# Considering feature set: [56, 116]
# Considering feature: 117
# Considering feature set: [56, 117]
# Considering feature: 118
# Considering feature set: [56, 118]
# Considering feature: 119
# Considering feature set: [56, 119]
# Considering feature: 120
# Considering feature set: [56, 120]
# Considering feature: 121
# Considering feature set: [56, 121]
# Considering feature: 122
# Considering feature set: [56, 122]
# Considering feature: 123
# Considering feature set: [56, 123]
# Considering feature: 124
# Considering feature set: [56, 124]
# Considering feature: 125
# Considering feature set: [56, 125]
# Considering feature: 126
# Considering feature set: [56, 126]
# Considering feature: 127
# Considering feature set: [56, 127]
# Considering feature: 128
# Considering feature set: [56, 128]
# Considering feature: 129
# Considering feature set: [56, 129]
# Considering feature: 130
# Considering feature set: [56, 130]
# Considering feature: 131
# Considering feature set: [56, 131]
# Considering feature: 132
# Considering feature set: [56, 132]
# Considering feature: 133
# Considering feature set: [56, 133]
# Considering feature: 134
# Considering feature set: [56, 134]
# Considering feature: 135
# Considering feature set: [56, 135]
# Considering feature: 136
# Considering feature set: [56, 136]
# Considering feature: 137
# Considering feature set: [56, 137]
# Considering feature: 138
# Considering feature set: [56, 138]
# Considering feature: 139
# Considering feature set: [56, 139]
# Considering feature: 140
# Considering feature set: [56, 140]
# Considering feature: 141
# Considering feature set: [56, 141]
# Considering feature: 142
# Considering feature set: [56, 142]
# Considering feature: 143
# Considering feature set: [56, 143]
# Considering feature: 144
# Considering feature set: [56, 144]
# Considering feature: 145
# Considering feature set: [56, 145]
# Considering feature: 146
# Considering feature set: [56, 146]
# Considering feature: 147
# Considering feature set: [56, 147]
# Considering feature: 148
# Considering feature set: [56, 148]
# Considering feature: 149
# Considering feature set: [56, 149]
# Considering feature: 150
# Considering feature set: [56, 150]
# Considering feature: 151
# Considering feature set: [56, 151]
# Considering feature: 152
# Considering feature set: [56, 152]
# Considering feature: 153
# Considering feature set: [56, 153]
# Considering feature: 154
# Considering feature set: [56, 154]
# Considering feature: 155
# Considering feature set: [56, 155]
# Considering feature: 156
# Considering feature set: [56, 156]
# Considering feature: 157
# Considering feature set: [56, 157]
# Considering feature: 158
# Considering feature set: [56, 158]
# Considering feature: 159
# Considering feature set: [56, 159]
# Considering feature: 160
# Considering feature set: [56, 160]
# Considering feature: 161
# Considering feature set: [56, 161]
# found new min cost for 2 features:
#                                 old min_cost 0.0005143350035359798, new min_cost: 0.0004966556516885659. diff = 1.767935184741388e-05
#                                 old selected_features [56, 13], new selected_features: [56, 161]
# Considering feature: 162
# Considering feature set: [56, 162]
# Considering feature: 163
# Considering feature set: [56, 163]
# Considering feature: 164
# Considering feature set: [56, 164]
# Considering feature: 165
# Considering feature set: [56, 165]
# Considering feature: 166
# Considering feature set: [56, 166]
# Considering feature: 167
# Considering feature set: [56, 167]
# Considering feature: 168
# Considering feature set: [56, 168]
# Considering feature: 169
# Considering feature set: [56, 169]
# Considering feature: 0
# Considering feature set: [56, 161, 0]
# Considering feature: 1
# Considering feature set: [56, 161, 1]
# Considering feature: 2
# Considering feature set: [56, 161, 2]
# Considering feature: 3
# Considering feature set: [56, 161, 3]
# Considering feature: 4
# Considering feature set: [56, 161, 4]
# Considering feature: 5
# Considering feature set: [56, 161, 5]
# found new min cost for 3 features:
#                                 old min_cost 0.000488366160478843, new min_cost: 0.00044161260949910394. diff = 4.675355097973901e-05
#                                 old selected_features [56, 161, 0], new selected_features: [56, 161, 5]
# Considering feature: 6
# Considering feature set: [56, 161, 6]
# Considering feature: 7
# Considering feature set: [56, 161, 7]
# Considering feature: 8
# Considering feature set: [56, 161, 8]
# Considering feature: 9
# Considering feature set: [56, 161, 9]
# Considering feature: 10
# Considering feature set: [56, 161, 10]
# Considering feature: 11
# Considering feature set: [56, 161, 11]
# Considering feature: 12
# Considering feature set: [56, 161, 12]
# Considering feature: 13
# Considering feature set: [56, 161, 13]
# Considering feature: 14
# Considering feature set: [56, 161, 14]
# Considering feature: 15
# Considering feature set: [56, 161, 15]
# Considering feature: 16
# Considering feature set: [56, 161, 16]
# Considering feature: 17
# Considering feature set: [56, 161, 17]
# Considering feature: 18
# Considering feature set: [56, 161, 18]
# Considering feature: 19
# Considering feature set: [56, 161, 19]
# Considering feature: 20
# Considering feature set: [56, 161, 20]
# Considering feature: 21
# Considering feature set: [56, 161, 21]
# Considering feature: 22
# Considering feature set: [56, 161, 22]
# found new min cost for 3 features:
#                                 old min_cost 0.00044161260949910394, new min_cost: 0.0004254734474356173. diff = 1.613916206348663e-05
#                                 old selected_features [56, 161, 5], new selected_features: [56, 161, 22]
# Considering feature: 23
# Considering feature set: [56, 161, 23]
# Considering feature: 24
# Considering feature set: [56, 161, 24]
# Considering feature: 25
# Considering feature set: [56, 161, 25]
# Considering feature: 26
# Considering feature set: [56, 161, 26]
# Considering feature: 27
# Considering feature set: [56, 161, 27]
# Considering feature: 28
# Considering feature set: [56, 161, 28]
# Considering feature: 29
# Considering feature set: [56, 161, 29]
# Considering feature: 30
# Considering feature set: [56, 161, 30]
# Considering feature: 31
# Considering feature set: [56, 161, 31]
# Considering feature: 32
# Considering feature set: [56, 161, 32]
# Considering feature: 33
# Considering feature set: [56, 161, 33]
# Considering feature: 34
# Considering feature set: [56, 161, 34]
# Considering feature: 35
# Considering feature set: [56, 161, 35]
# Considering feature: 36
# Considering feature set: [56, 161, 36]
# Considering feature: 37
# Considering feature set: [56, 161, 37]
# Considering feature: 38
# Considering feature set: [56, 161, 38]
# found new min cost for 3 features:
#                                 old min_cost 0.0004254734474356173, new min_cost: 0.00042008887959798336. diff = 5.384567837633943e-06
#                                 old selected_features [56, 161, 22], new selected_features: [56, 161, 38]
# Considering feature: 39
# Considering feature set: [56, 161, 39]
# Considering feature: 40
# Considering feature set: [56, 161, 40]
# Considering feature: 41
# Considering feature set: [56, 161, 41]
# Considering feature: 42
# Considering feature set: [56, 161, 42]
# Considering feature: 43
# Considering feature set: [56, 161, 43]
# Considering feature: 44
# Considering feature set: [56, 161, 44]
# Considering feature: 45
# Considering feature set: [56, 161, 45]
# Considering feature: 46
# Considering feature set: [56, 161, 46]
# Considering feature: 47
# Considering feature set: [56, 161, 47]
# Considering feature: 48
# Considering feature set: [56, 161, 48]
# Considering feature: 49
# Considering feature set: [56, 161, 49]
# Considering feature: 50
# Considering feature set: [56, 161, 50]
# Considering feature: 51
# Considering feature set: [56, 161, 51]
# Considering feature: 52
# Considering feature set: [56, 161, 52]
# Considering feature: 53
# Considering feature set: [56, 161, 53]
# Considering feature: 54
# Considering feature set: [56, 161, 54]
# Considering feature: 55
# Considering feature set: [56, 161, 55]
# Considering feature: 57
# Considering feature set: [56, 161, 57]
# Considering feature: 58
# Considering feature set: [56, 161, 58]
# Considering feature: 59
# Considering feature set: [56, 161, 59]
# Considering feature: 60
# Considering feature set: [56, 161, 60]
# Considering feature: 61
# Considering feature set: [56, 161, 61]
# Considering feature: 62
# Considering feature set: [56, 161, 62]
# Considering feature: 63
# Considering feature set: [56, 161, 63]
# Considering feature: 64
# Considering feature set: [56, 161, 64]
# Considering feature: 65
# Considering feature set: [56, 161, 65]
# Considering feature: 66
# Considering feature set: [56, 161, 66]
# Considering feature: 67
# Considering feature set: [56, 161, 67]
# Considering feature: 68
# Considering feature set: [56, 161, 68]
# Considering feature: 69
# Considering feature set: [56, 161, 69]
# Considering feature: 70
# Considering feature set: [56, 161, 70]
# Considering feature: 71
# Considering feature set: [56, 161, 71]
# Considering feature: 72
# Considering feature set: [56, 161, 72]
# Considering feature: 73
# Considering feature set: [56, 161, 73]
# Considering feature: 74
# Considering feature set: [56, 161, 74]
# Considering feature: 75
# Considering feature set: [56, 161, 75]
# Considering feature: 76
# Considering feature set: [56, 161, 76]
# Considering feature: 77
# Considering feature set: [56, 161, 77]
# Considering feature: 78
# Considering feature set: [56, 161, 78]
# Considering feature: 79
# Considering feature set: [56, 161, 79]
# Considering feature: 80
# Considering feature set: [56, 161, 80]
# Considering feature: 81
# Considering feature set: [56, 161, 81]
# Considering feature: 82
# Considering feature set: [56, 161, 82]
# Considering feature: 83
# Considering feature set: [56, 161, 83]
# Considering feature: 84
# Considering feature set: [56, 161, 84]
# Considering feature: 85
# Considering feature set: [56, 161, 85]
# Considering feature: 86
# Considering feature set: [56, 161, 86]
# Considering feature: 87
# Considering feature set: [56, 161, 87]
# Considering feature: 88
# Considering feature set: [56, 161, 88]
# Considering feature: 89
# Considering feature set: [56, 161, 89]
# Considering feature: 90
# Considering feature set: [56, 161, 90]
# Considering feature: 91
# Considering feature set: [56, 161, 91]
# Considering feature: 92
# Considering feature set: [56, 161, 92]
# Considering feature: 93
# Considering feature set: [56, 161, 93]
# Considering feature: 94
# Considering feature set: [56, 161, 94]
# Considering feature: 95
# Considering feature set: [56, 161, 95]
# Considering feature: 96
# Considering feature set: [56, 161, 96]
# Considering feature: 97
# Considering feature set: [56, 161, 97]
# Considering feature: 98
# Considering feature set: [56, 161, 98]
# Considering feature: 99
# Considering feature set: [56, 161, 99]
# Considering feature: 100
# Considering feature set: [56, 161, 100]
# Considering feature: 101
# Considering feature set: [56, 161, 101]
# Considering feature: 102
# Considering feature set: [56, 161, 102]
# Considering feature: 103
# Considering feature set: [56, 161, 103]
# Considering feature: 104
# Considering feature set: [56, 161, 104]
# Considering feature: 105
# Considering feature set: [56, 161, 105]
# Considering feature: 106
# Considering feature set: [56, 161, 106]
# Considering feature: 107
# Considering feature set: [56, 161, 107]
# Considering feature: 108
# Considering feature set: [56, 161, 108]
# Considering feature: 109
# Considering feature set: [56, 161, 109]
# Considering feature: 110
# Considering feature set: [56, 161, 110]
# Considering feature: 111
# Considering feature set: [56, 161, 111]
# Considering feature: 112
# Considering feature set: [56, 161, 112]
# Considering feature: 113
# Considering feature set: [56, 161, 113]
# Considering feature: 114
# Considering feature set: [56, 161, 114]
# Considering feature: 115
# Considering feature set: [56, 161, 115]
# Considering feature: 116
# Considering feature set: [56, 161, 116]
# Considering feature: 117
# Considering feature set: [56, 161, 117]
# Considering feature: 118
# Considering feature set: [56, 161, 118]
# Considering feature: 119
# Considering feature set: [56, 161, 119]
# Considering feature: 120
# Considering feature set: [56, 161, 120]
# Considering feature: 121
# Considering feature set: [56, 161, 121]
# Considering feature: 122
# Considering feature set: [56, 161, 122]
# Considering feature: 123
# Considering feature set: [56, 161, 123]
# Considering feature: 124
# Considering feature set: [56, 161, 124]
# Considering feature: 125
# Considering feature set: [56, 161, 125]
# Considering feature: 126
# Considering feature set: [56, 161, 126]
# Considering feature: 127
# Considering feature set: [56, 161, 127]
# Considering feature: 128
# Considering feature set: [56, 161, 128]
# Considering feature: 129
# Considering feature set: [56, 161, 129]
# Considering feature: 130
# Considering feature set: [56, 161, 130]
# Considering feature: 131
# Considering feature set: [56, 161, 131]
# Considering feature: 132
# Considering feature set: [56, 161, 132]
# Considering feature: 133
# Considering feature set: [56, 161, 133]
# Considering feature: 134
# Considering feature set: [56, 161, 134]
# Considering feature: 135
# Considering feature set: [56, 161, 135]
# Considering feature: 136
# Considering feature set: [56, 161, 136]
# Considering feature: 137
# Considering feature set: [56, 161, 137]
# Considering feature: 138
# Considering feature set: [56, 161, 138]
# Considering feature: 139
# Considering feature set: [56, 161, 139]
# Considering feature: 140
# Considering feature set: [56, 161, 140]
# Considering feature: 141
# Considering feature set: [56, 161, 141]
# Considering feature: 142
# Considering feature set: [56, 161, 142]
# Considering feature: 143
# Considering feature set: [56, 161, 143]
# Considering feature: 144
# Considering feature set: [56, 161, 144]
# Considering feature: 145
# Considering feature set: [56, 161, 145]
# Considering feature: 146
# Considering feature set: [56, 161, 146]
# Considering feature: 147
# Considering feature set: [56, 161, 147]
# Considering feature: 148
# Considering feature set: [56, 161, 148]
# Considering feature: 149
# Considering feature set: [56, 161, 149]
# Considering feature: 150
# Considering feature set: [56, 161, 150]
# Considering feature: 151
# Considering feature set: [56, 161, 151]
# Considering feature: 152
# Considering feature set: [56, 161, 152]
# Considering feature: 153
# Considering feature set: [56, 161, 153]
# Considering feature: 154
# Considering feature set: [56, 161, 154]
# Considering feature: 155
# Considering feature set: [56, 161, 155]
# Considering feature: 156
# Considering feature set: [56, 161, 156]
# Considering feature: 157
# Considering feature set: [56, 161, 157]
# Considering feature: 158
# Considering feature set: [56, 161, 158]
# Considering feature: 159
# Considering feature set: [56, 161, 159]
# Considering feature: 160
# Considering feature set: [56, 161, 160]
# Considering feature: 162
# Considering feature set: [56, 161, 162]
# Considering feature: 163
# Considering feature set: [56, 161, 163]
# Considering feature: 164
# Considering feature set: [56, 161, 164]
# Considering feature: 165
# Considering feature set: [56, 161, 165]
# Considering feature: 166
# Considering feature set: [56, 161, 166]
# Considering feature: 167
# Considering feature set: [56, 161, 167]
# Considering feature: 168
# Considering feature set: [56, 161, 168]
# Considering feature: 169
# Considering feature set: [56, 161, 169]
# Considering feature: 0
# Considering feature set: [56, 161, 38, 0]
# Considering feature: 1
# Considering feature set: [56, 161, 38, 1]
# Considering feature: 2
# Considering feature set: [56, 161, 38, 2]
# Considering feature: 3
# Considering feature set: [56, 161, 38, 3]
# Considering feature: 4
# Considering feature set: [56, 161, 38, 4]
# Considering feature: 5
# Considering feature set: [56, 161, 38, 5]
# Considering feature: 6
# Considering feature set: [56, 161, 38, 6]
# found new min cost for 4 features:
#                                 old min_cost 0.00041448495841239476, new min_cost: 0.00041128873784745544. diff = 3.19622056493932e-06
#                                 old selected_features [56, 161, 38, 0], new selected_features: [56, 161, 38, 6]
# Considering feature: 7
# Considering feature set: [56, 161, 38, 7]
# Considering feature: 8
# Considering feature set: [56, 161, 38, 8]
# Considering feature: 9
# Considering feature set: [56, 161, 38, 9]
# Considering feature: 10
# Considering feature set: [56, 161, 38, 10]
# found new min cost for 4 features:
#                                 old min_cost 0.00041128873784745544, new min_cost: 0.00039711701509576584. diff = 1.4171722751689603e-05
#                                 old selected_features [56, 161, 38, 6], new selected_features: [56, 161, 38, 10]
# Considering feature: 11
# Considering feature set: [56, 161, 38, 11]
# Considering feature: 12
# Considering feature set: [56, 161, 38, 12]
# Considering feature: 13
# Considering feature set: [56, 161, 38, 13]
# Considering feature: 14
# Considering feature set: [56, 161, 38, 14]
# Considering feature: 15
# Considering feature set: [56, 161, 38, 15]
# Considering feature: 16
# Considering feature set: [56, 161, 38, 16]
# Considering feature: 17
# Considering feature set: [56, 161, 38, 17]
# Considering feature: 18
# Considering feature set: [56, 161, 38, 18]
# Considering feature: 19
# Considering feature set: [56, 161, 38, 19]
# Considering feature: 20
# Considering feature set: [56, 161, 38, 20]
# Considering feature: 21
# Considering feature set: [56, 161, 38, 21]
# Considering feature: 22
# Considering feature set: [56, 161, 38, 22]
# Considering feature: 23
# Considering feature set: [56, 161, 38, 23]
# Considering feature: 24
# Considering feature set: [56, 161, 38, 24]
# Considering feature: 25
# Considering feature set: [56, 161, 38, 25]
# Considering feature: 26
# Considering feature set: [56, 161, 38, 26]
# Considering feature: 27
# Considering feature set: [56, 161, 38, 27]
# Considering feature: 28
# Considering feature set: [56, 161, 38, 28]
# Considering feature: 29
# Considering feature set: [56, 161, 38, 29]
# Considering feature: 30
# Considering feature set: [56, 161, 38, 30]
# Considering feature: 31
# Considering feature set: [56, 161, 38, 31]
# Considering feature: 32
# Considering feature set: [56, 161, 38, 32]
# Considering feature: 33
# Considering feature set: [56, 161, 38, 33]
# Considering feature: 34
# Considering feature set: [56, 161, 38, 34]
# Considering feature: 35
# Considering feature set: [56, 161, 38, 35]
# Considering feature: 36
# Considering feature set: [56, 161, 38, 36]
# Considering feature: 37
# Considering feature set: [56, 161, 38, 37]
# Considering feature: 39
# Considering feature set: [56, 161, 38, 39]
# Considering feature: 40
# Considering feature set: [56, 161, 38, 40]
# Considering feature: 41
# Considering feature set: [56, 161, 38, 41]
# Considering feature: 42
# Considering feature set: [56, 161, 38, 42]
# Considering feature: 43
# Considering feature set: [56, 161, 38, 43]
# Considering feature: 44
# Considering feature set: [56, 161, 38, 44]
# Considering feature: 45
# Considering feature set: [56, 161, 38, 45]
# Considering feature: 46
# Considering feature set: [56, 161, 38, 46]
# Considering feature: 47
# Considering feature set: [56, 161, 38, 47]
# Considering feature: 48
# Considering feature set: [56, 161, 38, 48]
# Considering feature: 49
# Considering feature set: [56, 161, 38, 49]
# Considering feature: 50
# Considering feature set: [56, 161, 38, 50]
# Considering feature: 51
# Considering feature set: [56, 161, 38, 51]
# Considering feature: 52
# Considering feature set: [56, 161, 38, 52]
# Considering feature: 53
# Considering feature set: [56, 161, 38, 53]
# Considering feature: 54
# Considering feature set: [56, 161, 38, 54]
# Considering feature: 55
# Considering feature set: [56, 161, 38, 55]
# Considering feature: 57
# Considering feature set: [56, 161, 38, 57]
# Considering feature: 58
# Considering feature set: [56, 161, 38, 58]
# Considering feature: 59
# Considering feature set: [56, 161, 38, 59]
# Considering feature: 60
# Considering feature set: [56, 161, 38, 60]
# Considering feature: 61
# Considering feature set: [56, 161, 38, 61]
# Considering feature: 62
# Considering feature set: [56, 161, 38, 62]
# Considering feature: 63
# Considering feature set: [56, 161, 38, 63]
# Considering feature: 64
# Considering feature set: [56, 161, 38, 64]
# Considering feature: 65
# Considering feature set: [56, 161, 38, 65]
# Considering feature: 66
# Considering feature set: [56, 161, 38, 66]
# Considering feature: 67
# Considering feature set: [56, 161, 38, 67]
# Considering feature: 68
# Considering feature set: [56, 161, 38, 68]
# Considering feature: 69
# Considering feature set: [56, 161, 38, 69]
# Considering feature: 70
# Considering feature set: [56, 161, 38, 70]
# Considering feature: 71
# Considering feature set: [56, 161, 38, 71]
# Considering feature: 72
# Considering feature set: [56, 161, 38, 72]
# Considering feature: 73
# Considering feature set: [56, 161, 38, 73]
# Considering feature: 74
# Considering feature set: [56, 161, 38, 74]
# Considering feature: 75
# Considering feature set: [56, 161, 38, 75]
# Considering feature: 76
# Considering feature set: [56, 161, 38, 76]
# Considering feature: 77
# Considering feature set: [56, 161, 38, 77]
# Considering feature: 78
# Considering feature set: [56, 161, 38, 78]
# Considering feature: 79
# Considering feature set: [56, 161, 38, 79]
# Considering feature: 80
# Considering feature set: [56, 161, 38, 80]
# Considering feature: 81
# Considering feature set: [56, 161, 38, 81]
# Considering feature: 82
# Considering feature set: [56, 161, 38, 82]
# Considering feature: 83
# Considering feature set: [56, 161, 38, 83]
# Considering feature: 84
# Considering feature set: [56, 161, 38, 84]
# Considering feature: 85
# Considering feature set: [56, 161, 38, 85]
# Considering feature: 86
# Considering feature set: [56, 161, 38, 86]
# Considering feature: 87
# Considering feature set: [56, 161, 38, 87]
# Considering feature: 88
# Considering feature set: [56, 161, 38, 88]
# Considering feature: 89
# Considering feature set: [56, 161, 38, 89]
# Considering feature: 90
# Considering feature set: [56, 161, 38, 90]
# Considering feature: 91
# Considering feature set: [56, 161, 38, 91]
# Considering feature: 92
# Considering feature set: [56, 161, 38, 92]
# Considering feature: 93
# Considering feature set: [56, 161, 38, 93]
# Considering feature: 94
# Considering feature set: [56, 161, 38, 94]
# Considering feature: 95
# Considering feature set: [56, 161, 38, 95]
# Considering feature: 96
# Considering feature set: [56, 161, 38, 96]
# Considering feature: 97
# Considering feature set: [56, 161, 38, 97]
# Considering feature: 98
# Considering feature set: [56, 161, 38, 98]
# Considering feature: 99
# Considering feature set: [56, 161, 38, 99]
# Considering feature: 100
# Considering feature set: [56, 161, 38, 100]
# Considering feature: 101
# Considering feature set: [56, 161, 38, 101]
# Considering feature: 102
# Considering feature set: [56, 161, 38, 102]
# Considering feature: 103
# Considering feature set: [56, 161, 38, 103]
# Considering feature: 104
# Considering feature set: [56, 161, 38, 104]
# Considering feature: 105
# Considering feature set: [56, 161, 38, 105]
# Considering feature: 106
# Considering feature set: [56, 161, 38, 106]
# Considering feature: 107
# Considering feature set: [56, 161, 38, 107]
# Considering feature: 108
# Considering feature set: [56, 161, 38, 108]
# Considering feature: 109
# Considering feature set: [56, 161, 38, 109]
# Considering feature: 110
# Considering feature set: [56, 161, 38, 110]
# Considering feature: 111
# Considering feature set: [56, 161, 38, 111]
# Considering feature: 112
# Considering feature set: [56, 161, 38, 112]
# Considering feature: 113
# Considering feature set: [56, 161, 38, 113]
# Considering feature: 114
# Considering feature set: [56, 161, 38, 114]
# Considering feature: 115
# Considering feature set: [56, 161, 38, 115]
# Considering feature: 116
# Considering feature set: [56, 161, 38, 116]
# Considering feature: 117
# Considering feature set: [56, 161, 38, 117]
# Considering feature: 118
# Considering feature set: [56, 161, 38, 118]
# Considering feature: 119
# Considering feature set: [56, 161, 38, 119]
# Considering feature: 120
# Considering feature set: [56, 161, 38, 120]
# Considering feature: 121
# Considering feature set: [56, 161, 38, 121]
# Considering feature: 122
# Considering feature set: [56, 161, 38, 122]
# Considering feature: 123
# Considering feature set: [56, 161, 38, 123]
# Considering feature: 124
# Considering feature set: [56, 161, 38, 124]
# Considering feature: 125
# Considering feature set: [56, 161, 38, 125]
# Considering feature: 126
# Considering feature set: [56, 161, 38, 126]
# Considering feature: 127
# Considering feature set: [56, 161, 38, 127]
# Considering feature: 128
# Considering feature set: [56, 161, 38, 128]
# Considering feature: 129
# Considering feature set: [56, 161, 38, 129]
# Considering feature: 130
# Considering feature set: [56, 161, 38, 130]
# Considering feature: 131
# Considering feature set: [56, 161, 38, 131]
# Considering feature: 132
# Considering feature set: [56, 161, 38, 132]
# Considering feature: 133
# Considering feature set: [56, 161, 38, 133]
# Considering feature: 134
# Considering feature set: [56, 161, 38, 134]
# Considering feature: 135
# Considering feature set: [56, 161, 38, 135]
# Considering feature: 136
# Considering feature set: [56, 161, 38, 136]
# Considering feature: 137
# Considering feature set: [56, 161, 38, 137]
# Considering feature: 138
# Considering feature set: [56, 161, 38, 138]
# Considering feature: 139
# Considering feature set: [56, 161, 38, 139]
# Considering feature: 140
# Considering feature set: [56, 161, 38, 140]
# Considering feature: 141
# Considering feature set: [56, 161, 38, 141]
# Considering feature: 142
# Considering feature set: [56, 161, 38, 142]
# found new min cost for 4 features:
#                                 old min_cost 0.00039711701509576584, new min_cost: 0.00039623445858873364. diff = 8.82556507032198e-07
#                                 old selected_features [56, 161, 38, 10], new selected_features: [56, 161, 38, 142]
# Considering feature: 143
# Considering feature set: [56, 161, 38, 143]
# Considering feature: 144
# Considering feature set: [56, 161, 38, 144]
# found new min cost for 4 features:
#                                 old min_cost 0.00039623445858873364, new min_cost: 0.00039584202761891836. diff = 3.9243096981527413e-07
#                                 old selected_features [56, 161, 38, 142], new selected_features: [56, 161, 38, 144]
# Considering feature: 145
# Considering feature set: [56, 161, 38, 145]
# Considering feature: 146
# Considering feature set: [56, 161, 38, 146]
# Considering feature: 147
# Considering feature set: [56, 161, 38, 147]
# Considering feature: 148
# Considering feature set: [56, 161, 38, 148]
# Considering feature: 149
# Considering feature set: [56, 161, 38, 149]
# Considering feature: 150
# Considering feature set: [56, 161, 38, 150]
# Considering feature: 151
# Considering feature set: [56, 161, 38, 151]
# Considering feature: 152
# Considering feature set: [56, 161, 38, 152]
# Considering feature: 153
# Considering feature set: [56, 161, 38, 153]
# Considering feature: 154
# Considering feature set: [56, 161, 38, 154]
# Considering feature: 155
# Considering feature set: [56, 161, 38, 155]
# Considering feature: 156
# Considering feature set: [56, 161, 38, 156]
# Considering feature: 157
# Considering feature set: [56, 161, 38, 157]
# Considering feature: 158
# Considering feature set: [56, 161, 38, 158]
# Considering feature: 159
# Considering feature set: [56, 161, 38, 159]
# Considering feature: 160
# Considering feature set: [56, 161, 38, 160]
# Considering feature: 162
# Considering feature set: [56, 161, 38, 162]
# Considering feature: 163
# Considering feature set: [56, 161, 38, 163]
# Considering feature: 164
# Considering feature set: [56, 161, 38, 164]
# Considering feature: 165
# Considering feature set: [56, 161, 38, 165]
# Considering feature: 166
# Considering feature set: [56, 161, 38, 166]
# Considering feature: 167
# Considering feature set: [56, 161, 38, 167]
# Considering feature: 168
# Considering feature set: [56, 161, 38, 168]
# Considering feature: 169
# Considering feature set: [56, 161, 38, 169]
# Considering feature: 0
# Considering feature set: [56, 161, 38, 144, 0]
# Considering feature: 1
# Considering feature set: [56, 161, 38, 144, 1]
# Considering feature: 2
# Considering feature set: [56, 161, 38, 144, 2]
# found new min cost for 5 features:
#                                 old min_cost 0.00038904226547772897, new min_cost: 0.00038804117202653044. diff = 1.001093451198534e-06
#                                 old selected_features [56, 161, 38, 144, 0], new selected_features: [56, 161, 38, 144, 2]
# Considering feature: 3
# Considering feature set: [56, 161, 38, 144, 3]
# Considering feature: 4
# Considering feature set: [56, 161, 38, 144, 4]
# Considering feature: 5
# Considering feature set: [56, 161, 38, 144, 5]
# Considering feature: 6
# Considering feature set: [56, 161, 38, 144, 6]
# Considering feature: 7
# Considering feature set: [56, 161, 38, 144, 7]
# Considering feature: 8
# Considering feature set: [56, 161, 38, 144, 8]
# Considering feature: 9
# Considering feature set: [56, 161, 38, 144, 9]
# Considering feature: 10
# Considering feature set: [56, 161, 38, 144, 10]
# Considering feature: 11
# Considering feature set: [56, 161, 38, 144, 11]
# Considering feature: 12
# Considering feature set: [56, 161, 38, 144, 12]
# found new min cost for 5 features:
#                                 old min_cost 0.00038804117202653044, new min_cost: 0.00038563769199576763. diff = 2.4034800307628037e-06
#                                 old selected_features [56, 161, 38, 144, 2], new selected_features: [56, 161, 38, 144, 12]
# Considering feature: 13
# Considering feature set: [56, 161, 38, 144, 13]
# Considering feature: 14
# Considering feature set: [56, 161, 38, 144, 14]
# Considering feature: 15
# Considering feature set: [56, 161, 38, 144, 15]
# Considering feature: 16
# Considering feature set: [56, 161, 38, 144, 16]
# Considering feature: 17
# Considering feature set: [56, 161, 38, 144, 17]
# Considering feature: 18
# Considering feature set: [56, 161, 38, 144, 18]
# Considering feature: 19
# Considering feature set: [56, 161, 38, 144, 19]
# Considering feature: 20
# Considering feature set: [56, 161, 38, 144, 20]
# Considering feature: 21
# Considering feature set: [56, 161, 38, 144, 21]
# Considering feature: 22
# Considering feature set: [56, 161, 38, 144, 22]
# Considering feature: 23
# Considering feature set: [56, 161, 38, 144, 23]
# Considering feature: 24
# Considering feature set: [56, 161, 38, 144, 24]
# Considering feature: 25
# Considering feature set: [56, 161, 38, 144, 25]
# Considering feature: 26
# Considering feature set: [56, 161, 38, 144, 26]
# Considering feature: 27
# Considering feature set: [56, 161, 38, 144, 27]
# Considering feature: 28
# Considering feature set: [56, 161, 38, 144, 28]
# Considering feature: 29
# Considering feature set: [56, 161, 38, 144, 29]
# Considering feature: 30
# Considering feature set: [56, 161, 38, 144, 30]
# Considering feature: 31
# Considering feature set: [56, 161, 38, 144, 31]
# Considering feature: 32
# Considering feature set: [56, 161, 38, 144, 32]
# Considering feature: 33
# Considering feature set: [56, 161, 38, 144, 33]
# Considering feature: 34
# Considering feature set: [56, 161, 38, 144, 34]
# Considering feature: 35
# Considering feature set: [56, 161, 38, 144, 35]
# Considering feature: 36
# Considering feature set: [56, 161, 38, 144, 36]
# Considering feature: 37
# Considering feature set: [56, 161, 38, 144, 37]
# Considering feature: 39
# Considering feature set: [56, 161, 38, 144, 39]
# Considering feature: 40
# Considering feature set: [56, 161, 38, 144, 40]
# Considering feature: 41
# Considering feature set: [56, 161, 38, 144, 41]
# Considering feature: 42
# Considering feature set: [56, 161, 38, 144, 42]
# found new min cost for 5 features:
#                                 old min_cost 0.00038563769199576763, new min_cost: 0.0003852805467166644. diff = 3.5714527910323804e-07
#                                 old selected_features [56, 161, 38, 144, 12], new selected_features: [56, 161, 38, 144, 42]
# Considering feature: 43
# Considering feature set: [56, 161, 38, 144, 43]
# Considering feature: 44
# Considering feature set: [56, 161, 38, 144, 44]
# Considering feature: 45
# Considering feature set: [56, 161, 38, 144, 45]
# Considering feature: 46
# Considering feature set: [56, 161, 38, 144, 46]
# Considering feature: 47
# Considering feature set: [56, 161, 38, 144, 47]
# Considering feature: 48
# Considering feature set: [56, 161, 38, 144, 48]
# Considering feature: 49
# Considering feature set: [56, 161, 38, 144, 49]
# Considering feature: 50
# Considering feature set: [56, 161, 38, 144, 50]
# Considering feature: 51
# Considering feature set: [56, 161, 38, 144, 51]
# Considering feature: 52
# Considering feature set: [56, 161, 38, 144, 52]
# Considering feature: 53
# Considering feature set: [56, 161, 38, 144, 53]
# Considering feature: 54
# Considering feature set: [56, 161, 38, 144, 54]
# Considering feature: 55
# Considering feature set: [56, 161, 38, 144, 55]
# Considering feature: 57
# Considering feature set: [56, 161, 38, 144, 57]
# Considering feature: 58
# Considering feature set: [56, 161, 38, 144, 58]
# Considering feature: 59
# Considering feature set: [56, 161, 38, 144, 59]
# Considering feature: 60
# Considering feature set: [56, 161, 38, 144, 60]
# Considering feature: 61
# Considering feature set: [56, 161, 38, 144, 61]
# Considering feature: 62
# Considering feature set: [56, 161, 38, 144, 62]
# Considering feature: 63
# Considering feature set: [56, 161, 38, 144, 63]
# Considering feature: 64
# Considering feature set: [56, 161, 38, 144, 64]
# Considering feature: 65
# Considering feature set: [56, 161, 38, 144, 65]
# Considering feature: 66
# Considering feature set: [56, 161, 38, 144, 66]
# Considering feature: 67
# Considering feature set: [56, 161, 38, 144, 67]
# Considering feature: 68
# Considering feature set: [56, 161, 38, 144, 68]
# Considering feature: 69
# Considering feature set: [56, 161, 38, 144, 69]
# Considering feature: 70
# Considering feature set: [56, 161, 38, 144, 70]
# Considering feature: 71
# Considering feature set: [56, 161, 38, 144, 71]
# Considering feature: 72
# Considering feature set: [56, 161, 38, 144, 72]
# Considering feature: 73
# Considering feature set: [56, 161, 38, 144, 73]
# Considering feature: 74
# Considering feature set: [56, 161, 38, 144, 74]
# Considering feature: 75
# Considering feature set: [56, 161, 38, 144, 75]
# Considering feature: 76
# Considering feature set: [56, 161, 38, 144, 76]
# Considering feature: 77
# Considering feature set: [56, 161, 38, 144, 77]
# Considering feature: 78
# Considering feature set: [56, 161, 38, 144, 78]
# Considering feature: 79
# Considering feature set: [56, 161, 38, 144, 79]
# Considering feature: 80
# Considering feature set: [56, 161, 38, 144, 80]
# Considering feature: 81
# Considering feature set: [56, 161, 38, 144, 81]
# Considering feature: 82
# Considering feature set: [56, 161, 38, 144, 82]
# Considering feature: 83
# Considering feature set: [56, 161, 38, 144, 83]
# Considering feature: 84
# Considering feature set: [56, 161, 38, 144, 84]
# Considering feature: 85
# Considering feature set: [56, 161, 38, 144, 85]
# Considering feature: 86
# Considering feature set: [56, 161, 38, 144, 86]
# Considering feature: 87
# Considering feature set: [56, 161, 38, 144, 87]
# Considering feature: 88
# Considering feature set: [56, 161, 38, 144, 88]
# Considering feature: 89
# Considering feature set: [56, 161, 38, 144, 89]
# Considering feature: 90
# Considering feature set: [56, 161, 38, 144, 90]
# Considering feature: 91
# Considering feature set: [56, 161, 38, 144, 91]
# Considering feature: 92
# Considering feature set: [56, 161, 38, 144, 92]
# Considering feature: 93
# Considering feature set: [56, 161, 38, 144, 93]
# Considering feature: 94
# Considering feature set: [56, 161, 38, 144, 94]
# Considering feature: 95
# Considering feature set: [56, 161, 38, 144, 95]
# Considering feature: 96
# Considering feature set: [56, 161, 38, 144, 96]
# Considering feature: 97
# Considering feature set: [56, 161, 38, 144, 97]
# Considering feature: 98
# Considering feature set: [56, 161, 38, 144, 98]
# Considering feature: 99
# Considering feature set: [56, 161, 38, 144, 99]
# Considering feature: 100
# Considering feature set: [56, 161, 38, 144, 100]
# Considering feature: 101
# Considering feature set: [56, 161, 38, 144, 101]
# Considering feature: 102
# Considering feature set: [56, 161, 38, 144, 102]
# Considering feature: 103
# Considering feature set: [56, 161, 38, 144, 103]
# Considering feature: 104
# Considering feature set: [56, 161, 38, 144, 104]
# Considering feature: 105
# Considering feature set: [56, 161, 38, 144, 105]
# Considering feature: 106
# Considering feature set: [56, 161, 38, 144, 106]
# Considering feature: 107
# Considering feature set: [56, 161, 38, 144, 107]
# Considering feature: 108
# Considering feature set: [56, 161, 38, 144, 108]
# Considering feature: 109
# Considering feature set: [56, 161, 38, 144, 109]
# Considering feature: 110
# Considering feature set: [56, 161, 38, 144, 110]
# Considering feature: 111
# Considering feature set: [56, 161, 38, 144, 111]
# Considering feature: 112
# Considering feature set: [56, 161, 38, 144, 112]
# Considering feature: 113
# Considering feature set: [56, 161, 38, 144, 113]
# Considering feature: 114
# Considering feature set: [56, 161, 38, 144, 114]
# Considering feature: 115
# Considering feature set: [56, 161, 38, 144, 115]
# Considering feature: 116
# Considering feature set: [56, 161, 38, 144, 116]
# Considering feature: 117
# Considering feature set: [56, 161, 38, 144, 117]
# Considering feature: 118
# Considering feature set: [56, 161, 38, 144, 118]
# Considering feature: 119
# Considering feature set: [56, 161, 38, 144, 119]
# Considering feature: 120
# Considering feature set: [56, 161, 38, 144, 120]
# Considering feature: 121
# Considering feature set: [56, 161, 38, 144, 121]
# Considering feature: 122
# Considering feature set: [56, 161, 38, 144, 122]
# Considering feature: 123
# Considering feature set: [56, 161, 38, 144, 123]
# Considering feature: 124
# Considering feature set: [56, 161, 38, 144, 124]
# Considering feature: 125
# Considering feature set: [56, 161, 38, 144, 125]
# Considering feature: 126
# Considering feature set: [56, 161, 38, 144, 126]
# Considering feature: 127
# Considering feature set: [56, 161, 38, 144, 127]
# Considering feature: 128
# Considering feature set: [56, 161, 38, 144, 128]
# Considering feature: 129
# Considering feature set: [56, 161, 38, 144, 129]
# Considering feature: 130
# Considering feature set: [56, 161, 38, 144, 130]
# Considering feature: 131
# Considering feature set: [56, 161, 38, 144, 131]
# Considering feature: 132
# Considering feature set: [56, 161, 38, 144, 132]
# Considering feature: 133
# Considering feature set: [56, 161, 38, 144, 133]
# Considering feature: 134
# Considering feature set: [56, 161, 38, 144, 134]
# Considering feature: 135
# Considering feature set: [56, 161, 38, 144, 135]
# Considering feature: 136
# Considering feature set: [56, 161, 38, 144, 136]
# Considering feature: 137
# Considering feature set: [56, 161, 38, 144, 137]
# Considering feature: 138
# Considering feature set: [56, 161, 38, 144, 138]
# Considering feature: 139
# Considering feature set: [56, 161, 38, 144, 139]
# Considering feature: 140
# Considering feature set: [56, 161, 38, 144, 140]
# Considering feature: 141
# Considering feature set: [56, 161, 38, 144, 141]
# Considering feature: 142
# Considering feature set: [56, 161, 38, 144, 142]
# Considering feature: 143
# Considering feature set: [56, 161, 38, 144, 143]
# Considering feature: 145
# Considering feature set: [56, 161, 38, 144, 145]
# Considering feature: 146
# Considering feature set: [56, 161, 38, 144, 146]
# Considering feature: 147
# Considering feature set: [56, 161, 38, 144, 147]
# Considering feature: 148
# Considering feature set: [56, 161, 38, 144, 148]
# Considering feature: 149
# Considering feature set: [56, 161, 38, 144, 149]
# Considering feature: 150
# Considering feature set: [56, 161, 38, 144, 150]
# Considering feature: 151
# Considering feature set: [56, 161, 38, 144, 151]
# Considering feature: 152
# Considering feature set: [56, 161, 38, 144, 152]
# Considering feature: 153
# Considering feature set: [56, 161, 38, 144, 153]
# Considering feature: 154
# Considering feature set: [56, 161, 38, 144, 154]
# Considering feature: 155
# Considering feature set: [56, 161, 38, 144, 155]
# Considering feature: 156
# Considering feature set: [56, 161, 38, 144, 156]
# Considering feature: 157
# Considering feature set: [56, 161, 38, 144, 157]
# Considering feature: 158
# Considering feature set: [56, 161, 38, 144, 158]
# Considering feature: 159
# Considering feature set: [56, 161, 38, 144, 159]
# Considering feature: 160
# Considering feature set: [56, 161, 38, 144, 160]
# Considering feature: 162
# Considering feature set: [56, 161, 38, 144, 162]
# Considering feature: 163
# Considering feature set: [56, 161, 38, 144, 163]
# Considering feature: 164
# Considering feature set: [56, 161, 38, 144, 164]
# Considering feature: 165
# Considering feature set: [56, 161, 38, 144, 165]
# Considering feature: 166
# Considering feature set: [56, 161, 38, 144, 166]
# Considering feature: 167
# Considering feature set: [56, 161, 38, 144, 167]
# Considering feature: 168
# Considering feature set: [56, 161, 38, 144, 168]
# Considering feature: 169
# Considering feature set: [56, 161, 38, 144, 169]

# %%
for feature in ffs:
    print(feature_names[feature])
# Out:
# sqft_living * grade
# lat * long
# bathrooms * waterfront
# yr_built * zipcode
# bathrooms * sqft_above
