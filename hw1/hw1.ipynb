# %% [markdown]
# # Exercise 1: Linear Regression
#
# ## Do not start the exercise until you fully understand the submission guidelines.
#
#
# * The homework assignments are executed automatically.
# * Failure to comply with the following instructions will result in a significant penalty.
# * Appeals regarding your failure to read these instructions will be denied.
# * Kindly reminder: the homework assignments contribute 50% of the final grade.
#
#
# ## Read the following instructions carefully:
#
# 1. This Jupyter notebook contains all the step-by-step instructions needed for this exercise.
# 1. Write **efficient**, **vectorized** code whenever possible. Some calculations in this exercise may take several minutes when implemented efficiently, and might take much longer otherwise. Unnecessary loops will result in point deductions.
# 1. You are responsible for the correctness of your code and should add as many tests as you see fit to this jupyter notebook. Tests will not be graded nor checked.
# 1. Complete the required functions in `hw1.py` script only. This exercise is graded automatically, and only the `hw1.py` script is tested.
# 1. You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/), numpy and pandas only. **Do not import anything else.**
# 1. Your code must run without errors. Use at least `numpy` 1.15.4. Any code that cannot run will not be graded.
# 1. Write your own code. Cheating will not be tolerated.
# 1. Submission includes a zip file that contains the hw1.py script as well as this notebook, with your ID as the file name. For example, `hw1_123456789_987654321.zip` if you submitted in pairs and `hw1_123456789.zip` if you submitted the exercise alone.
# Please use only a **zip** file in your submission.
#
# ---
# ---
#
# ## Please sign that you have read and understood the instructions:
#
# 208951111, 322315755
# ---
# ---

# %%
import numpy as np # used for scientific computing
import pandas as pd # used for data analysis and manipulation
import matplotlib.pyplot as plt # used for visualization and plotting
np.random.seed(42) 

# make the notebook automatically reload external python modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Part 1: Data Preprocessing (10 Points)
#
# For the following exercise, we will use a dataset containing housing prices in King County, USA. The dataset contains 5,000 observations with 18 features and a single target value - the house price.
#
# First, we will read and explore the data using pandas and the `.read_csv` method. Pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %%
# Read comma separated data
df = pd.read_csv('data.csv')
# df stands for dataframe, which is the default format for datasets in pandas

# %% [markdown]
# ### Data Exploration
# A good practice in any data-oriented project is to first try and understand the data. Fortunately, pandas is built for that purpose. Start by looking at the top of the dataset using the `df.head()` command. This will be the first indication that you read your data properly, and that the headers are correct. Next, you can use `df.describe()` to show statistics on the data and check for trends and irregularities.

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  yr_built  \
# 0      5650     1.0           0     0          3      7        1180      1955
# 1      7242     2.0           0     0          3      7        2170      1951
# 2     10000     1.0           0     0          3      6         770      1933
# 3      5000     1.0           0     0          5      7        1050      1965
# 4      8080     1.0           0     0          3      8        1680      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
df.describe()
# Out:
#                  id         price   bedrooms    bathrooms   sqft_living  \
# count  5.000000e+03  5.000000e+03  5000.0000  5000.000000   5000.000000
# mean   4.630823e+09  5.394699e+05     3.3714     2.062150   2061.036800
# std    2.870890e+09  3.873115e+05     0.9104     0.773592    923.727509
# min    1.000102e+06  7.500000e+04     0.0000     0.000000    380.000000
# 25%    2.154075e+09  3.179062e+05     3.0000     1.500000   1410.000000
# 50%    4.022900e+09  4.490000e+05     3.0000     2.000000   1890.000000
# 75%    7.345078e+09  6.500000e+05     4.0000     2.500000   2500.000000
# max    9.842300e+09  7.060000e+06     9.0000     6.750000  10040.000000
#
#            sqft_lot       floors   waterfront         view    condition  \
# count  5.000000e+03  5000.000000  5000.000000  5000.000000  5000.000000
# mean   1.615893e+04     1.432600     0.009400     0.243000     3.455000
# std    4.600220e+04     0.510793     0.096506     0.774643     0.677692
# min    6.090000e+02     1.000000     0.000000     0.000000     1.000000
# 25%    5.400000e+03     1.000000     0.000000     0.000000     3.000000
# 50%    7.875000e+03     1.000000     0.000000     0.000000     3.000000
# 75%    1.123400e+04     2.000000     0.000000     0.000000     4.000000
# max    1.651359e+06     3.500000     1.000000     4.000000     5.000000
#
#              grade   sqft_above     yr_built  yr_renovated       zipcode  \
# count  5000.000000  5000.000000  5000.000000   5000.000000   5000.000000
# mean      7.595200  1753.151000  1966.660800     95.052800  98078.812600
# std       1.166537   818.390844    28.286855    425.234932     54.126332
# min       3.000000   380.000000  1900.000000      0.000000  98001.000000
# 25%       7.000000  1190.000000  1949.000000      0.000000  98033.000000
# 50%       7.000000  1530.000000  1968.000000      0.000000  98070.000000
# 75%       8.000000  2130.000000  1990.000000      0.000000  98118.000000
# max      13.000000  7680.000000  2015.000000   2015.000000  98199.000000
#
#                lat         long  sqft_living15     sqft_lot15
# count  5000.000000  5000.000000     5000.00000    5000.000000
# mean     47.559312  -122.215864     1976.84520   13451.164600
# std       0.139521     0.141807      674.73601   26514.749009
# min      47.155900  -122.514000      620.00000     660.000000
# 25%      47.463675  -122.329000     1490.00000    5391.500000
# 50%      47.572850  -122.235000     1820.00000    7800.000000
# 75%      47.679200  -122.129000     2340.00000   10469.250000
# max      47.777600  -121.315000     5790.00000  434728.000000

# %% [markdown]
# We will start with one variable linear regression by extracting the target column and the `sqft_living` variable from the dataset. We use pandas and select both columns as separate variables and transform them into a numpy array.

# %%
X = df['sqft_living'].values
y = df['price'].values

# %% [markdown]
# ## Preprocessing
#
# As the number of features grows, calculating gradients gets computationally expensive. We can speed this up by normalizing the input data to ensure all values are within the same range. This is especially important for datasets with high standard deviations or differences in the ranges of the attributes. Use [mean normalization](https://en.wikipedia.org/wiki/Feature_scaling) for the fearures (`X`) and the true labels (`y`).
#
# Your implementation should not contain loops.
#
# ---
# Open `hw1.py` and complete the function `preprocess`. (5 points)

# %%
from hw1 import preprocess

X, y = preprocess(X, y)
X.shape, y.shape
# Out:
# ((5000, 170), (5000,))

# %% [markdown]
# We will split the data into two datasets:
# 1. The training dataset will contain 80% of the data and will always be used for model training.
# 2. The validation dataset will contain the remaining 20% of the data and will be used for model evaluation. For example, we will pick the best alpha and the best features using the validation dataset, while still training the model using the training dataset.

# %%
# training and validation split
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train], X[idx_val]
y_train, y_val = y[idx_train], y[idx_val]

# %% [markdown]
# ## Data Visualization
# Another useful tool is data visualization. Since this problem has only two parameters, it is possible to create a two-dimensional scatter plot to visualize the data. Note that many real-world datasets are highly dimensional and cannot be visualized naively. We will be using `matplotlib` for all data visualization purposes since it offers a wide range of visualization tools and is easy to use.

# %%
plt.plot(X_train, y_train, 'ro', ms=1, mec='k') # the parameters control the size, shape and color of the scatter plot
plt.ylabel('Price in USD')
plt.xlabel('sq.ft')
plt.show()

# %% [markdown]
# ## Bias Trick
#
# Make sure that `X` takes into consideration the bias $\theta_0$ in the linear model. Hint, recall that the predications of our linear model are of the form:
#
# $$
# \hat{y} = h_\theta(x) = \theta^T x = \theta_0 + \theta_1 x_1
# $$
#
# Add columns of ones as the zeroth column of the features (do this for both the training and validation sets).
#
# ---
# Open `hw1.py` and complete the function `apply_bias_trick`. (5 points)

# %%
from hw1 import apply_bias_trick

X_train = apply_bias_trick(X_train)
X_val = apply_bias_trick(X_val)

X_train.shape, X_val.shape
# Out:
# ((4000, 2), (1000, 2))

# %% [markdown]
# ## Part 2: Single Variable Linear Regression (60 Points)
# Simple linear regression is a linear regression model with a single explanatory varaible and a single target value.
#
# $$
# \hat{y} = h_\theta(x) = \theta^T x = \theta_0 + \theta_1 x_1
# $$
#
# ## Gradient Descent
#
# Our task is to find the best possible linear line that explains all the points in our dataset. We start by guessing initial values for the linear regression parameters $\theta$ and updating the values using gradient descent.
#
# The objective of linear regression is to minimize the cost function $J$:
#
# $$
# J(\theta) = \frac{1}{2m} \sum_{i=1}^{m}(h_\theta(x^{(i)})-y^{(i)})^2
# $$
#
# where the hypothesis (model) $h_\theta(x)$ is given by a **linear** model:
#
# $$
# h_\theta(x) = \theta^T x = \theta_0 + \theta_1 x_1
# $$
#
# $\theta_j$ are parameters of your model. and by changing those values accordingly you will be able to lower the cost function $J(\theta)$. One way to accopmlish this is to use gradient descent:
#
# $$
# \theta_j = \theta_j - \alpha \frac{1}{m} \sum_{i=1}^m (h_\theta(x^{(i)})-y^{(i)})x_j^{(i)}
# $$
#
# In linear regresion, we know that with each step of gradient descent, the parameters $\theta_j$ get closer to the optimal values that will achieve the lowest cost $J(\theta)$.
#
# ---
#
# Open `hw1.py` and complete the function `compute_cost`. (10 points)

# %%
from hw1 import compute_cost
theta = np.array([-1, 2])
J = compute_cost(X_train, y_train, theta)

# %% [markdown]
# Open `hw1.py` and complete the function `gradient_descent`. (30 points)

# %%
from hw1 import gradient_descent

np.random.seed(42)
theta = np.random.random(size=2)
iterations = 40000
alpha = 0.1
theta, J_history = gradient_descent(X_train ,y_train, theta, alpha, iterations)
# Out:
# theta [0.37454012 0.95071431], for cost: 0.07244667608564773
# Iter: 0 New theta arrived: [0.33704811 0.95017267], for cost: 0.059090085022239086
# Iter: 1 New theta arrived: [0.30330536 0.9496355 ], for cost: 0.04827077592584292
# Iter: 2 New theta arrived: [0.27293695 0.94910241], for cost: 0.03950666558098812
# Iter: 3 New theta arrived: [0.24560543 0.94857303], for cost: 0.03240726667985374
# Iter: 4 New theta arrived: [0.22100712 0.94804703], for cost: 0.026656284581135427
# Iter: 5 New theta arrived: [0.19886869 0.94752413], for cost: 0.021997520688276897
# Iter: 6 New theta arrived: [0.17894417 0.94700406], for cost: 0.018223454188712403
# Iter: 7 New theta arrived: [0.16101215 0.94648658], for cost: 0.01516599326498329
# Iter: 8 New theta arrived: [0.14487339 0.94597148], for cost: 0.012688983577627605
# Iter: 9 New theta arrived: [0.13034856 0.94545857], for cost: 0.01068214013784962
# Iter: 10 New theta arrived: [0.11727626 0.94494768], for cost: 0.009056132125619266
# Iter: 11 New theta arrived: [0.10551125 0.94443864], for cost: 0.007738601593335892
# Iter: 12 New theta arrived: [0.0949228  0.94393131], for cost: 0.00667093861660739
# Iter: 13 New theta arrived: [0.08539324 0.94342559], for cost: 0.0058056691670393835
# Iter: 14 New theta arrived: [0.0768167  0.94292133], for cost: 0.005104339289727078
# Iter: 15 New theta arrived: [0.06909786 0.94241846], for cost: 0.004535801287455518
# Iter: 16 New theta arrived: [0.06215096 0.94191687], for cost: 0.004074825530251004
# Iter: 17 New theta arrived: [0.0558988  0.94141648], for cost: 0.0037009760214011126
# Iter: 18 New theta arrived: [0.05027191 0.94091721], for cost: 0.003397699606160229
# Iter: 19 New theta arrived: [0.04520776 0.940419  ], for cost: 0.0031515882309867786
# Iter: 20 New theta arrived: [0.04065008 0.93992179], for cost: 0.0029517813736758018
# Iter: 21 New theta arrived: [0.03654822 0.93942553], for cost: 0.0027894820118883387
# Iter: 22 New theta arrived: [0.0328566  0.93893016], for cost: 0.0026575645577588606
# Iter: 23 New theta arrived: [0.0295342  0.93843564], for cost: 0.002550257285007326
# Iter: 24 New theta arrived: [0.02654408 0.93794193], for cost: 0.002462885094964624
# Iter: 25 New theta arrived: [0.02385303 0.93744899], for cost: 0.002391661157105737
# Iter: 26 New theta arrived: [0.02143114 0.93695679], for cost: 0.0023335181379240573
# Iter: 27 New theta arrived: [0.01925149 0.93646531], for cost: 0.0022859714963540116
# Iter: 28 New theta arrived: [0.01728986 0.93597452], for cost: 0.002247008753091249
# Iter: 29 New theta arrived: [0.01552444 0.93548438], for cost: 0.002214999798764597
# Iter: 30 New theta arrived: [0.01393561 0.93499489], for cost: 0.0021886242435736245
# Iter: 31 New theta arrived: [0.01250572 0.93450602], for cost: 0.0021668125705098713
# Iter: 32 New theta arrived: [0.01121887 0.93401775], for cost: 0.002148698469478078
# Iter: 33 New theta arrived: [0.01006076 0.93353007], for cost: 0.002133580227944029
# Iter: 34 New theta arrived: [0.00901851 0.93304297], for cost: 0.0021208894573672846
# Iter: 35 New theta arrived: [0.00808054 0.93255643], for cost: 0.002110165761617919
# Iter: 36 New theta arrived: [0.00723641 0.93207043], for cost: 0.002101036218399424
# Iter: 37 New theta arrived: [0.00647675 0.93158498], for cost: 0.0020931987592052365
# Iter: 38 New theta arrived: [0.00579311 0.93110006], for cost: 0.0020864087070871073
# Iter: 39 New theta arrived: [0.00517788 0.93061566], for cost: 0.002080467872250067
# Iter: 40 New theta arrived: [0.00462423 0.93013177], for cost: 0.002075215719486654
# Iter: 41 New theta arrived: [0.00412599 0.92964839], for cost: 0.0020705222138004097
# Iter: 42 New theta arrived: [0.00367763 0.92916551], for cost: 0.0020662820253623706
# Iter: 43 New theta arrived: [0.00327416 0.92868312], for cost: 0.0020624098355269587
# Iter: 44 New theta arrived: [0.00291108 0.92820123], for cost: 0.002058836534705892
# Iter: 45 New theta arrived: [0.00258436 0.92771982], for cost: 0.002055506142646762
# Iter: 46 New theta arrived: [0.00229037 0.92723889], for cost: 0.0020523733138593033
# Iter: 47 New theta arrived: [0.00202582 0.92675843], for cost: 0.0020494013170111926
# Iter: 48 New theta arrived: [0.00178779 0.92627845], for cost: 0.0020465603982390487
# Iter: 49 New theta arrived: [0.0015736  0.92579894], for cost: 0.0020438264554306983
# Iter: 50 New theta arrived: [0.00138089 0.9253199 ], for cost: 0.0020411799643939832
# Iter: 51 New theta arrived: [0.00120749 0.92484132], for cost: 0.0020386051090538777
# Iter: 52 New theta arrived: [0.00105149 0.9243632 ], for cost: 0.0020360890769121264
# Iter: 53 New theta arrived: [9.11140352e-04 9.23885543e-01], for cost: 0.0020336214883698188
# Iter: 54 New theta arrived: [7.84874443e-04 9.23408341e-01], for cost: 0.002031193934478804
# Iter: 55 New theta arrived: [6.71285687e-04 9.22931595e-01], for cost: 0.0020287996025202867
# Iter: 56 New theta arrived: [5.69106322e-04 9.22455303e-01], for cost: 0.002026432972723705
# Iter: 57 New theta arrived: [4.77195360e-04 9.21979462e-01], for cost: 0.002024089572609043
# Iter: 58 New theta arrived: [3.94525912e-04 9.21504072e-01], for cost: 0.002021765778004062
# Iter: 59 New theta arrived: [3.20173781e-04 9.21029131e-01], for cost: 0.0020194586518684134
# Iter: 60 New theta arrived: [2.53307186e-04 9.20554638e-01], for cost: 0.002017165813741145
# Iter: 61 New theta arrived: [1.93177526e-04 9.20080591e-01], for cost: 0.002014885333993162
# Iter: 62 New theta arrived: [1.39111061e-04 9.19606990e-01], for cost: 0.002012615648171824
# Iter: 63 New theta arrived: [9.05014235e-05 9.19133833e-01], for cost: 0.002010355487620022
# Iter: 64 New theta arrived: [4.68028843e-05 9.18661119e-01], for cost: 0.0020081038232776095
# Iter: 65 New theta arrived: [7.52428630e-06 9.18188848e-01], for cost: 0.002005859820160695
# Iter: 66 New theta arrived: [-2.77764115e-05  9.17717019e-01], for cost: 0.0020036228004897193
# Iter: 67 New theta arrived: [-5.94970458e-05  9.17245630e-01], for cost: 0.0020013922138232975
# Iter: 68 New theta arrived: [-8.79956697e-05  9.16774681e-01], for cost: 0.001999167612866606
# Iter: 69 New theta arrived: [-1.13594531e-04  9.16304172e-01], for cost: 0.0019969486338761657
# Iter: 70 New theta arrived: [-1.36583652e-04  9.15834101e-01], for cost: 0.0019947349807877693
# Iter: 71 New theta arrived: [-1.57224054e-04  9.15364468e-01], for cost: 0.001992526412359986
# Iter: 72 New theta arrived: [-1.75750655e-04  9.14895272e-01], for cost: 0.0019903227317605047
# Iter: 73 New theta arrived: [-1.92374881e-04  9.14426513e-01], for cost: 0.001988123778131065
# Iter: 74 New theta arrived: [-2.07287016e-04  9.13958189e-01], for cost: 0.001985929419754962
# Iter: 75 New theta arrived: [-2.20658315e-04  9.13490301e-01], for cost: 0.0019837395485228044
# Iter: 76 New theta arrived: [-2.32642909e-04  9.13022848e-01], for cost: 0.0019815540754497527
# Iter: 77 New theta arrived: [-2.43379513e-04  9.12555828e-01], for cost: 0.001979372927044453
# Iter: 78 New theta arrived: [-2.52992973e-04  9.12089243e-01], for cost: 0.001977196042367906
# Iter: 79 New theta arrived: [-2.61595648e-04  9.11623091e-01], for cost: 0.0019750233706511185
# Iter: 80 New theta arrived: [-2.69288664e-04  9.11157371e-01], for cost: 0.001972854869365415
# Iter: 81 New theta arrived: [-2.76163033e-04  9.10692084e-01], for cost: 0.0019706905026593744
# Iter: 82 New theta arrived: [-2.82300663e-04  9.10227228e-01], for cost: 0.0019685302400927404
# Iter: 83 New theta arrived: [-2.87775277e-04  9.09762803e-01], for cost: 0.0019663740556109107
# Iter: 84 New theta arrived: [-2.92653219e-04  9.09298810e-01], for cost: 0.001964221926714236
# Iter: 85 New theta arrived: [-2.96994204e-04  9.08835246e-01], for cost: 0.00196207383378516
# Iter: 86 New theta arrived: [-3.00851973e-04  9.08372112e-01], for cost: 0.0019599297595432287
# Iter: 87 New theta arrived: [-3.04274893e-04  9.07909408e-01], for cost: 0.001957789688603551
# Iter: 88 New theta arrived: [-3.07306493e-04  9.07447133e-01], for cost: 0.001955653607119274
# Iter: 89 New theta arrived: [-3.09985953e-04  9.06985286e-01], for cost: 0.0019535215024918994
# Iter: 90 New theta arrived: [-3.12348530e-04  9.06523867e-01], for cost: 0.0019513933631366428
# Iter: 91 New theta arrived: [-3.14425960e-04  9.06062876e-01], for cost: 0.0019492691782923913
# Iter: 92 New theta arrived: [-3.16246801e-04  9.05602312e-01], for cost: 0.001947148937867765
# Iter: 93 New theta arrived: [-3.17836758e-04  9.05142175e-01], for cost: 0.0019450326323163986
# Iter: 94 New theta arrived: [-3.19218964e-04  9.04682464e-01], for cost: 0.00194292025253593
# Iter: 95 New theta arrived: [-3.20414240e-04  9.04223179e-01], for cost: 0.0019408117897861952
# Iter: 96 New theta arrived: [-3.21441324e-04  9.03764319e-01], for cost: 0.001938707235622906
# Iter: 97 New theta arrived: [-3.22317081e-04  9.03305885e-01], for cost: 0.0019366065818440046
# Iter: 98 New theta arrived: [-3.23056687e-04  9.02847875e-01], for cost: 0.0019345098204461147
# Iter: 99 New theta arrived: [-3.23673803e-04  9.02390290e-01], for cost: 0.0019324169435893657
# Iter: 100 New theta arrived: [-3.24180724e-04  9.01933129e-01], for cost: 0.001930327943568771
# Iter: 101 New theta arrived: [-3.24588512e-04  9.01476391e-01], for cost: 0.0019282428127911577
# Iter: 102 New theta arrived: [-3.24907128e-04  9.01020076e-01], for cost: 0.0019261615437564134
# Iter: 103 New theta arrived: [-3.25145532e-04  9.00564184e-01], for cost: 0.0019240841290423135
# Iter: 104 New theta arrived: [-3.25311791e-04  9.00108714e-01], for cost: 0.0019220105612921818
# Iter: 105 New theta arrived: [-3.25413163e-04  8.99653666e-01], for cost: 0.0019199408332049505
# Iter: 106 New theta arrived: [-3.25456183e-04  8.99199039e-01], for cost: 0.0019178749375270867
# Iter: 107 New theta arrived: [-3.25446730e-04  8.98744834e-01], for cost: 0.0019158128670460422
# Iter: 510 New theta arrived: [-1.66441440e-04  7.46060496e-01], for cost: 0.001330903671943491
# Iter: 511 New theta arrived: [-1.66107355e-04  7.45748113e-01], for cost: 0.0013299282929100176
# Iter: 512 New theta arrived: [-1.65773579e-04  7.45436020e-01], for cost: 0.0013289547196446245
# Iter: 513 New theta arrived: [-1.65440112e-04  7.45124215e-01], for cost: 0.0013279829488042033
# Iter: 514 New theta arrived: [-1.65106954e-04  7.44812700e-01], for cost: 0.0013270129770518242
# Iter: 515 New theta arrived: [-1.64774104e-04  7.44501473e-01], for cost: 0.0013260448010567441
# Iter: 516 New theta arrived: [-1.64441563e-04  7.44190534e-01], for cost: 0.0013250784174943997
# Iter: 517 New theta arrived: [-1.64109329e-04  7.43879883e-01], for cost: 0.001324113823046353
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 7
#       5 iterations = 40000
#       6 alpha = 0.1
# ----> 7 theta, J_history = gradient_descent(X_train ,y_train, theta, alpha, iterations)
#
# File ~/Documents/code/idc/sem4/machine-learning-for-data/hw1/hw1.py:109, in gradient_descent(X, y, theta, alpha, num_iters, stop)
#     107 # update theta
#     108 theta = np.array(theta_temps)
# --> 109 cost = compute_cost(X, y, theta)
#     110 J_history.append(cost)
#     111 if debug:
#
# File ~/Documents/code/idc/sem4/machine-learning-for-data/hw1/hw1.py:64, in compute_cost(X, y, theta)
#      62 sigma = 0.0
#      63 for i in range(m):
# ---> 64     sigma+=(_compute_hypothesis(X[i], theta)-y[i]) ** 2
#      66 return (1.0/(2*m)) * (sigma)
#
# KeyboardInterrupt:

# %% [markdown]
# You can evaluate the learning process by monitoring the loss as training progress. In the following graph, we visualize the loss as a function of the iterations. This is possible since we are saving the loss value at every iteration in the `J_history` array. This visualization might help you find problems with your code. Notice that since the network converges quickly, we are using logarithmic scale for the number of iterations.

# %%
plt.plot(np.arange(iterations), J_history)
plt.xscale('log')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations')
plt.show()

# %% [markdown]
# The pseudo inverse solution is a direct approach to finding the best-fitting parameters of the linear model. In your implementation, **do not use `np.linalg.pinv`**. Instead, use only direct matrix multiplication as you saw in class (you can calculate the inverse of a matrix using `np.linalg.inv`).
#
# ---
# Open `hw1.py` and complete the function `compute_pinv`. (10 points)

# %%
from hw1 import compute_pinv

# %%
theta_pinv = compute_pinv(X_train ,y_train)
J_pinv = compute_cost(X_train, y_train, theta_pinv)

# %% [markdown]
# We can add the loss value for the theta calculated using the psuedo-inverse to our graph. This is another sanity check as the loss of our model should converge to the psuedo-inverse loss.

# %%
plt.plot(np.arange(len(J_history)), J_history)
plt.xscale('log')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations')
plt.hlines(y = J_pinv, xmin = 0, xmax = len(J_history), color='r',
           linewidth = 1, linestyle = 'dashed')
plt.show()

# %% [markdown]
# We can use a better approach for the implementation of `gradient_descent`. Instead of performing 40,000 iterations, we wish to stop when the improvement of the loss value is smaller than `1e-8` from one iteration to the next.
#
# The learning rate is another factor that determines the performance of our model in terms of speed and accuracy. Complete the function `find_best_alpha`. Make sure you use the training dataset to learn the parameters (thetas) and use those parameters with the validation dataset to compute the cost.
#
# **After implementing `efficient_gradient_descent` and finding the best alpha value, use them for the rest of the exercise.**
#
# ---
# Open `hw1.py` and complete the function `efficient_gradient_descent` and `find_best_alpha`. (5 points each)

# %%
from hw1 import efficient_gradient_descent, find_best_alpha

# %%
alpha_dict = find_best_alpha(X_train, y_train, X_val, y_val, iterations)
# Out:
# Trying alpha: 1e-05
# theta [0.37454012 0.95071431], for cost: 0.07244667608564773
# Iter: 0 New theta arrived: [0.37453637 0.95071425], for cost: 0.07244527014875499
# Iter: 1 New theta arrived: [0.37453262 0.9507142 ], for cost: 0.07244386423997601
# Iter: 2 New theta arrived: [0.37452887 0.95071414], for cost: 0.07244245835930994
# Iter: 3 New theta arrived: [0.37452512 0.95071409], for cost: 0.07244105250675649
# Iter: 4 New theta arrived: [0.37452137 0.95071404], for cost: 0.07243964668231467
# Iter: 5 New theta arrived: [0.37451762 0.95071398], for cost: 0.07243824088598438
# Iter: 6 New theta arrived: [0.37451388 0.95071393], for cost: 0.07243683511776505
# Iter: 7 New theta arrived: [0.37451013 0.95071387], for cost: 0.07243542937765582
# Iter: 8 New theta arrived: [0.37450638 0.95071382], for cost: 0.07243402366565656
# Iter: 9 New theta arrived: [0.37450263 0.95071376], for cost: 0.07243261798176648
# Iter: 10 New theta arrived: [0.37449888 0.95071371], for cost: 0.07243121232598482
# Iter: 11 New theta arrived: [0.37449513 0.95071366], for cost: 0.07242980669831099
# Iter: 12 New theta arrived: [0.37449138 0.9507136 ], for cost: 0.07242840109874482
# Iter: 13 New theta arrived: [0.37448763 0.95071355], for cost: 0.07242699552728558
# Iter: 14 New theta arrived: [0.37448388 0.95071349], for cost: 0.07242558998393267
# Iter: 15 New theta arrived: [0.37448014 0.95071344], for cost: 0.07242418446868538
# Iter: 16 New theta arrived: [0.37447639 0.95071339], for cost: 0.07242277898154346
# Iter: 17 New theta arrived: [0.37447264 0.95071333], for cost: 0.07242137352250624
# Iter: 18 New theta arrived: [0.37446889 0.95071328], for cost: 0.07241996809157279
# Iter: 19 New theta arrived: [0.37446514 0.95071322], for cost: 0.07241856268874328
# Iter: 20 New theta arrived: [0.37446139 0.95071317], for cost: 0.07241715731401648
# Iter: 21 New theta arrived: [0.37445765 0.95071311], for cost: 0.07241575196739221
# Iter: 22 New theta arrived: [0.3744539  0.95071306], for cost: 0.07241434664886973
# Iter: 23 New theta arrived: [0.37445015 0.95071301], for cost: 0.07241294135844843
# Iter: 24 New theta arrived: [0.3744464  0.95071295], for cost: 0.07241153609612787
# Iter: 25 New theta arrived: [0.37444265 0.9507129 ], for cost: 0.0724101308619077
# Iter: 26 New theta arrived: [0.3744389  0.95071284], for cost: 0.07240872565578693
# Iter: 27 New theta arrived: [0.37443516 0.95071279], for cost: 0.07240732047776512
# Iter: 28 New theta arrived: [0.37443141 0.95071274], for cost: 0.07240591532784198
# Iter: 29 New theta arrived: [0.37442766 0.95071268], for cost: 0.07240451020601645
# Iter: 30 New theta arrived: [0.37442391 0.95071263], for cost: 0.07240310511228862
# Iter: 31 New theta arrived: [0.37442016 0.95071257], for cost: 0.07240170004665734
# Iter: 32 New theta arrived: [0.37441642 0.95071252], for cost: 0.0724002950091223
# Iter: 33 New theta arrived: [0.37441267 0.95071246], for cost: 0.07239888999968311
# Iter: 34 New theta arrived: [0.37440892 0.95071241], for cost: 0.0723974850183387
# Iter: 35 New theta arrived: [0.37440517 0.95071236], for cost: 0.07239608006508896
# Iter: 36 New theta arrived: [0.37440142 0.9507123 ], for cost: 0.0723946751399332
# Iter: 37 New theta arrived: [0.37439768 0.95071225], for cost: 0.07239327024287101
# Iter: 38 New theta arrived: [0.37439393 0.95071219], for cost: 0.07239186537390153
# Iter: 39 New theta arrived: [0.37439018 0.95071214], for cost: 0.0723904605330243
# Iter: 40 New theta arrived: [0.37438643 0.95071209], for cost: 0.07238905572023868
# Iter: 41 New theta arrived: [0.37438268 0.95071203], for cost: 0.07238765093554425
# Iter: 42 New theta arrived: [0.37437894 0.95071198], for cost: 0.0723862461789407
# Iter: 43 New theta arrived: [0.37437519 0.95071192], for cost: 0.07238484145042716
# Iter: 44 New theta arrived: [0.37437144 0.95071187], for cost: 0.07238343675000275
# Iter: 45 New theta arrived: [0.37436769 0.95071181], for cost: 0.07238203207766773
# Iter: 46 New theta arrived: [0.37436395 0.95071176], for cost: 0.07238062743342066
# Iter: 47 New theta arrived: [0.3743602  0.95071171], for cost: 0.07237922281726164
# Iter: 48 New theta arrived: [0.37435645 0.95071165], for cost: 0.07237781822918987
# Iter: 49 New theta arrived: [0.3743527 0.9507116], for cost: 0.07237641366920433
# Iter: 50 New theta arrived: [0.37434896 0.95071154], for cost: 0.07237500913730546
# Iter: 51 New theta arrived: [0.37434521 0.95071149], for cost: 0.07237360463349177
# Iter: 52 New theta arrived: [0.37434146 0.95071144], for cost: 0.07237220015776297
# Iter: 53 New theta arrived: [0.37433772 0.95071138], for cost: 0.0723707957101187
# Iter: 54 New theta arrived: [0.37433397 0.95071133], for cost: 0.07236939129055847
# Iter: 55 New theta arrived: [0.37433022 0.95071127], for cost: 0.07236798689908154
# Iter: 56 New theta arrived: [0.37432647 0.95071122], for cost: 0.07236658253568723
# Iter: 57 New theta arrived: [0.37432273 0.95071116], for cost: 0.07236517820037502
# Iter: 58 New theta arrived: [0.37431898 0.95071111], for cost: 0.07236377389314452
# Iter: 59 New theta arrived: [0.37431523 0.95071106], for cost: 0.07236236961399527
# Iter: 60 New theta arrived: [0.37431149 0.950711  ], for cost: 0.07236096536292629
# Iter: 61 New theta arrived: [0.37430774 0.95071095], for cost: 0.07235956113993713
# Iter: 62 New theta arrived: [0.37430399 0.95071089], for cost: 0.07235815694502784
# Iter: 63 New theta arrived: [0.37430025 0.95071084], for cost: 0.07235675277819684
# Iter: 64 New theta arrived: [0.3742965  0.95071079], for cost: 0.0723553486394441
# Iter: 65 New theta arrived: [0.37429275 0.95071073], for cost: 0.07235394452876928
# Iter: 66 New theta arrived: [0.37428901 0.95071068], for cost: 0.07235254044617141
# Iter: 67 New theta arrived: [0.37428526 0.95071062], for cost: 0.07235113639165043
# Iter: 68 New theta arrived: [0.37428151 0.95071057], for cost: 0.07234973236520507
# Iter: 69 New theta arrived: [0.37427777 0.95071052], for cost: 0.07234832836683538
# Iter: 70 New theta arrived: [0.37427402 0.95071046], for cost: 0.07234692439653992
# Iter: 71 New theta arrived: [0.37427027 0.95071041], for cost: 0.07234552045431987
# Iter: 72 New theta arrived: [0.37426653 0.95071035], for cost: 0.07234411654017299
# Iter: 73 New theta arrived: [0.37426278 0.9507103 ], for cost: 0.07234271265409921
# Iter: 74 New theta arrived: [0.37425903 0.95071024], for cost: 0.07234130879609812
# Iter: 75 New theta arrived: [0.37425529 0.95071019], for cost: 0.07233990496616884
# Iter: 76 New theta arrived: [0.37425154 0.95071014], for cost: 0.07233850116431158
# Iter: 77 New theta arrived: [0.37424779 0.95071008], for cost: 0.07233709739052498
# Iter: 78 New theta arrived: [0.37424405 0.95071003], for cost: 0.07233569364480888
# Iter: 79 New theta arrived: [0.3742403  0.95070997], for cost: 0.07233428992716252
# Iter: 80 New theta arrived: [0.37423656 0.95070992], for cost: 0.07233288623758533
# Iter: 81 New theta arrived: [0.37423281 0.95070987], for cost: 0.07233148257607706
# Iter: 82 New theta arrived: [0.37422906 0.95070981], for cost: 0.07233007894263692
# Iter: 83 New theta arrived: [0.37422532 0.95070976], for cost: 0.07232867533726403
# Iter: 84 New theta arrived: [0.37422157 0.9507097 ], for cost: 0.07232727175995834
# Iter: 85 New theta arrived: [0.37421782 0.95070965], for cost: 0.07232586821071939
# Iter: 86 New theta arrived: [0.37421408 0.95070959], for cost: 0.07232446468954581
# Iter: 87 New theta arrived: [0.37421033 0.95070954], for cost: 0.07232306119643808
# Iter: 88 New theta arrived: [0.37420659 0.95070949], for cost: 0.0723216577313944
# Iter: 89 New theta arrived: [0.37420284 0.95070943], for cost: 0.07232025429441591
# Iter: 90 New theta arrived: [0.3741991  0.95070938], for cost: 0.0723188508855006
# Iter: 91 New theta arrived: [0.37419535 0.95070932], for cost: 0.07231744750464862
# Iter: 92 New theta arrived: [0.3741916  0.95070927], for cost: 0.07231604415185852
# Iter: 93 New theta arrived: [0.37418786 0.95070922], for cost: 0.07231464082713075
# Iter: 94 New theta arrived: [0.37418411 0.95070916], for cost: 0.07231323753046422
# Iter: 95 New theta arrived: [0.37418037 0.95070911], for cost: 0.07231183426185891
# Iter: 96 New theta arrived: [0.37417662 0.95070905], for cost: 0.07231043102131365
# Iter: 97 New theta arrived: [0.37417288 0.950709  ], for cost: 0.07230902780882809
# Iter: 98 New theta arrived: [0.37416913 0.95070894], for cost: 0.07230762462440161
# Iter: 99 New theta arrived: [0.37416538 0.95070889], for cost: 0.07230622146803392
# Iter: 100 New theta arrived: [0.37416164 0.95070884], for cost: 0.07230481833972445
# Iter: 101 New theta arrived: [0.37415789 0.95070878], for cost: 0.07230341523947188
# Iter: 102 New theta arrived: [0.37415415 0.95070873], for cost: 0.07230201216727639
# Iter: 103 New theta arrived: [0.3741504  0.95070867], for cost: 0.07230060912313753
# Iter: 104 New theta arrived: [0.37414666 0.95070862], for cost: 0.07229920610705448
# Iter: 105 New theta arrived: [0.37414291 0.95070857], for cost: 0.07229780311902653
# Iter: 106 New theta arrived: [0.37413917 0.95070851], for cost: 0.07229640015905321
# Iter: 107 New theta arrived: [0.37413542 0.95070846], for cost: 0.07229499722713406
# Iter: 108 New theta arrived: [0.37413168 0.9507084 ], for cost: 0.0722935943232682
# Iter: 109 New theta arrived: [0.37412793 0.95070835], for cost: 0.0722921914474554
# Iter: 110 New theta arrived: [0.37412419 0.95070829], for cost: 0.07229078859969507
# Iter: 111 New theta arrived: [0.37412044 0.95070824], for cost: 0.0722893857799867
# Iter: 112 New theta arrived: [0.3741167  0.95070819], for cost: 0.07228798298832974
# Iter: 113 New theta arrived: [0.37411295 0.95070813], for cost: 0.07228658022472333
# Iter: 114 New theta arrived: [0.37410921 0.95070808], for cost: 0.07228517748916728
# Iter: 115 New theta arrived: [0.37410546 0.95070802], for cost: 0.07228377478166069
# Iter: 116 New theta arrived: [0.37410172 0.95070797], for cost: 0.07228237210220313
# Iter: 117 New theta arrived: [0.37409797 0.95070792], for cost: 0.07228096945079393
# Iter: 118 New theta arrived: [0.37409423 0.95070786], for cost: 0.07227956682743318
# Iter: 119 New theta arrived: [0.37409048 0.95070781], for cost: 0.07227816423211934
# Iter: 120 New theta arrived: [0.37408674 0.95070775], for cost: 0.07227676166485238
# Iter: 121 New theta arrived: [0.37408299 0.9507077 ], for cost: 0.07227535912563177
# Iter: 122 New theta arrived: [0.37407925 0.95070764], for cost: 0.07227395661445703
# Iter: 123 New theta arrived: [0.3740755  0.95070759], for cost: 0.07227255413132715
# Iter: 124 New theta arrived: [0.37407176 0.95070754], for cost: 0.07227115167624196
# Iter: 125 New theta arrived: [0.37406801 0.95070748], for cost: 0.07226974924920061
# Iter: 126 New theta arrived: [0.37406427 0.95070743], for cost: 0.07226834685020289
# Iter: 127 New theta arrived: [0.37406053 0.95070737], for cost: 0.07226694447924803
# Iter: 128 New theta arrived: [0.37405678 0.95070732], for cost: 0.07226554213633551
# Iter: 129 New theta arrived: [0.37405304 0.95070727], for cost: 0.07226413982146473
# Iter: 130 New theta arrived: [0.37404929 0.95070721], for cost: 0.07226273753463515
# Iter: 131 New theta arrived: [0.37404555 0.95070716], for cost: 0.07226133527584612
# Iter: 132 New theta arrived: [0.3740418 0.9507071], for cost: 0.07225993304509748
# Iter: 133 New theta arrived: [0.37403806 0.95070705], for cost: 0.07225853084238788
# Iter: 134 New theta arrived: [0.37403432 0.95070699], for cost: 0.07225712866771757
# Iter: 135 New theta arrived: [0.37403057 0.95070694], for cost: 0.07225572652108547
# Iter: 136 New theta arrived: [0.37402683 0.95070689], for cost: 0.07225432440249137
# Iter: 137 New theta arrived: [0.37402308 0.95070683], for cost: 0.07225292231193453
# Iter: 138 New theta arrived: [0.37401934 0.95070678], for cost: 0.07225152024941463
# Iter: 139 New theta arrived: [0.3740156  0.95070672], for cost: 0.07225011821493052
# Iter: 140 New theta arrived: [0.37401185 0.95070667], for cost: 0.07224871620848204
# Iter: 141 New theta arrived: [0.37400811 0.95070662], for cost: 0.07224731423006871
# Iter: 142 New theta arrived: [0.37400436 0.95070656], for cost: 0.07224591227968946
# Iter: 143 New theta arrived: [0.37400062 0.95070651], for cost: 0.07224451035734485
# Iter: 144 New theta arrived: [0.37399688 0.95070645], for cost: 0.07224310846303338
# Iter: 145 New theta arrived: [0.37399313 0.9507064 ], for cost: 0.07224170659675459
# Iter: 146 New theta arrived: [0.37398939 0.95070634], for cost: 0.07224030475850803
# Iter: 147 New theta arrived: [0.37398564 0.95070629], for cost: 0.07223890294829281
# Iter: 148 New theta arrived: [0.3739819  0.95070624], for cost: 0.07223750116610926
# Iter: 149 New theta arrived: [0.37397816 0.95070618], for cost: 0.07223609941195566
# Iter: 150 New theta arrived: [0.37397441 0.95070613], for cost: 0.07223469768583293
# Iter: 151 New theta arrived: [0.37397067 0.95070607], for cost: 0.07223329598773884
# Iter: 152 New theta arrived: [0.37396693 0.95070602], for cost: 0.07223189431767386
# Iter: 153 New theta arrived: [0.37396318 0.95070597], for cost: 0.07223049267563729
# Iter: 154 New theta arrived: [0.37395944 0.95070591], for cost: 0.07222909106162817
# Iter: 155 New theta arrived: [0.3739557  0.95070586], for cost: 0.07222768947564684
# Iter: 156 New theta arrived: [0.37395195 0.9507058 ], for cost: 0.07222628791769156
# Iter: 157 New theta arrived: [0.37394821 0.95070575], for cost: 0.07222488638776266
# Iter: 158 New theta arrived: [0.37394447 0.95070569], for cost: 0.07222348488585895
# Iter: 159 New theta arrived: [0.37394072 0.95070564], for cost: 0.0722220834119806
# Iter: 160 New theta arrived: [0.37393698 0.95070559], for cost: 0.07222068196612617
# Iter: 161 New theta arrived: [0.37393324 0.95070553], for cost: 0.07221928054829604
# Iter: 162 New theta arrived: [0.37392949 0.95070548], for cost: 0.07221787915848864
# Iter: 163 New theta arrived: [0.37392575 0.95070542], for cost: 0.07221647779670441
# Iter: 164 New theta arrived: [0.37392201 0.95070537], for cost: 0.07221507646294203
# Iter: 165 New theta arrived: [0.37391826 0.95070532], for cost: 0.07221367515720138
# Iter: 166 New theta arrived: [0.37391452 0.95070526], for cost: 0.07221227387948202
# Iter: 167 New theta arrived: [0.37391078 0.95070521], for cost: 0.07221087262978286
# Iter: 168 New theta arrived: [0.37390704 0.95070515], for cost: 0.07220947140810334
# Iter: 169 New theta arrived: [0.37390329 0.9507051 ], for cost: 0.07220807021444332
# Iter: 170 New theta arrived: [0.37389955 0.95070505], for cost: 0.07220666904880232
# Iter: 171 New theta arrived: [0.37389581 0.95070499], for cost: 0.07220526791117947
# Iter: 172 New theta arrived: [0.37389206 0.95070494], for cost: 0.07220386680157426
# Iter: 173 New theta arrived: [0.37388832 0.95070488], for cost: 0.07220246571998598
# Iter: 174 New theta arrived: [0.37388458 0.95070483], for cost: 0.07220106466641418
# Iter: 175 New theta arrived: [0.37388084 0.95070477], for cost: 0.0721996636408586
# Iter: 176 New theta arrived: [0.37387709 0.95070472], for cost: 0.07219826264331825
# Iter: 177 New theta arrived: [0.37387335 0.95070467], for cost: 0.07219686167379305
# Iter: 178 New theta arrived: [0.37386961 0.95070461], for cost: 0.07219546073228192
# Iter: 179 New theta arrived: [0.37386587 0.95070456], for cost: 0.07219405981878477
# Iter: 180 New theta arrived: [0.37386212 0.9507045 ], for cost: 0.07219265893330072
# Iter: 181 New theta arrived: [0.37385838 0.95070445], for cost: 0.07219125807582907
# Iter: 182 New theta arrived: [0.37385464 0.9507044 ], for cost: 0.0721898572463697
# Iter: 183 New theta arrived: [0.3738509  0.95070434], for cost: 0.07218845644492122
# Iter: 184 New theta arrived: [0.37384715 0.95070429], for cost: 0.07218705567148417
# Iter: 185 New theta arrived: [0.37384341 0.95070423], for cost: 0.0721856549260576
# Iter: 186 New theta arrived: [0.37383967 0.95070418], for cost: 0.07218425420864095
# Iter: 187 New theta arrived: [0.37383593 0.95070412], for cost: 0.07218285351923329
# Iter: 188 New theta arrived: [0.37383219 0.95070407], for cost: 0.07218145285783446
# Iter: 189 New theta arrived: [0.37382844 0.95070402], for cost: 0.07218005222444375
# Iter: 190 New theta arrived: [0.3738247  0.95070396], for cost: 0.07217865161906037
# Iter: 191 New theta arrived: [0.37382096 0.95070391], for cost: 0.07217725104168407
# Iter: 192 New theta arrived: [0.37381722 0.95070385], for cost: 0.07217585049231455
# Iter: 193 New theta arrived: [0.37381348 0.9507038 ], for cost: 0.07217444997095038
# Iter: 194 New theta arrived: [0.37380973 0.95070375], for cost: 0.07217304947759208
# Iter: 195 New theta arrived: [0.37380599 0.95070369], for cost: 0.0721716490122384
# Iter: 196 New theta arrived: [0.37380225 0.95070364], for cost: 0.0721702485748889
# Iter: 197 New theta arrived: [0.37379851 0.95070358], for cost: 0.07216884816554284
# Iter: 198 New theta arrived: [0.37379477 0.95070353], for cost: 0.07216744778420033
# Iter: 199 New theta arrived: [0.37379102 0.95070347], for cost: 0.07216604743085984
# Iter: 200 New theta arrived: [0.37378728 0.95070342], for cost: 0.07216464710552169
# Iter: 201 New theta arrived: [0.37378354 0.95070337], for cost: 0.0721632468081848
# Iter: 202 New theta arrived: [0.3737798  0.95070331], for cost: 0.07216184653884884
# Iter: 203 New theta arrived: [0.37377606 0.95070326], for cost: 0.07216044629751298
# Iter: 204 New theta arrived: [0.37377232 0.9507032 ], for cost: 0.0721590460841769
# Iter: 205 New theta arrived: [0.37376857 0.95070315], for cost: 0.07215764589884047
# Iter: 206 New theta arrived: [0.37376483 0.9507031 ], for cost: 0.07215624574150226
# Iter: 207 New theta arrived: [0.37376109 0.95070304], for cost: 0.07215484561216225
# Iter: 208 New theta arrived: [0.37375735 0.95070299], for cost: 0.07215344551081962
# Iter: 209 New theta arrived: [0.37375361 0.95070293], for cost: 0.07215204543747396
# Iter: 210 New theta arrived: [0.37374987 0.95070288], for cost: 0.07215064539212461
# Iter: 211 New theta arrived: [0.37374613 0.95070282], for cost: 0.07214924537477105
# Iter: 212 New theta arrived: [0.37374239 0.95070277], for cost: 0.07214784538541258
# Iter: 213 New theta arrived: [0.37373864 0.95070272], for cost: 0.07214644542404937
# Iter: 214 New theta arrived: [0.3737349  0.95070266], for cost: 0.0721450454906799
# Iter: 215 New theta arrived: [0.37373116 0.95070261], for cost: 0.07214364558530395
# Iter: 216 New theta arrived: [0.37372742 0.95070255], for cost: 0.07214224570792124
# Iter: 217 New theta arrived: [0.37372368 0.9507025 ], for cost: 0.07214084585853107
# Iter: 218 New theta arrived: [0.37371994 0.95070245], for cost: 0.07213944603713224
# Iter: 219 New theta arrived: [0.3737162  0.95070239], for cost: 0.07213804624372518
# Iter: 220 New theta arrived: [0.37371246 0.95070234], for cost: 0.07213664647830904
# Iter: 221 New theta arrived: [0.37370872 0.95070228], for cost: 0.07213524674088281
# Iter: 222 New theta arrived: [0.37370497 0.95070223], for cost: 0.07213384703144624
# Iter: 223 New theta arrived: [0.37370123 0.95070217], for cost: 0.07213244734999884
# Iter: 224 New theta arrived: [0.37369749 0.95070212], for cost: 0.07213104769653984
# Iter: 225 New theta arrived: [0.37369375 0.95070207], for cost: 0.07212964807106904
# Iter: 226 New theta arrived: [0.37369001 0.95070201], for cost: 0.07212824847358544
# Iter: 227 New theta arrived: [0.37368627 0.95070196], for cost: 0.07212684890408928
# Iter: 228 New theta arrived: [0.37368253 0.9507019 ], for cost: 0.07212544936257892
# Iter: 229 New theta arrived: [0.37367879 0.95070185], for cost: 0.07212404984905417
# Iter: 230 New theta arrived: [0.37367505 0.9507018 ], for cost: 0.0721226503635149
# Iter: 231 New theta arrived: [0.37367131 0.95070174], for cost: 0.07212125090595992
# Iter: 232 New theta arrived: [0.37366757 0.95070169], for cost: 0.07211985147638936
# Iter: 233 New theta arrived: [0.37366383 0.95070163], for cost: 0.07211845207480203
# Iter: 234 New theta arrived: [0.37366009 0.95070158], for cost: 0.07211705270119785
# Iter: 235 New theta arrived: [0.37365635 0.95070152], for cost: 0.07211565335557593
# Iter: 236 New theta arrived: [0.37365261 0.95070147], for cost: 0.07211425403793598
# Iter: 237 New theta arrived: [0.37364887 0.95070142], for cost: 0.07211285474827689
# Iter: 238 New theta arrived: [0.37364513 0.95070136], for cost: 0.07211145548659888
# Iter: 239 New theta arrived: [0.37364139 0.95070131], for cost: 0.07211005625290105
# Iter: 240 New theta arrived: [0.37363764 0.95070125], for cost: 0.07210865704718249
# Iter: 241 New theta arrived: [0.3736339 0.9507012], for cost: 0.07210725786944311
# Iter: 242 New theta arrived: [0.37363016 0.95070115], for cost: 0.07210585871968225
# Iter: 243 New theta arrived: [0.37362642 0.95070109], for cost: 0.07210445959789932
# Iter: 244 New theta arrived: [0.37362268 0.95070104], for cost: 0.07210306050409357
# Iter: 245 New theta arrived: [0.37361894 0.95070098], for cost: 0.07210166143826477
# Iter: 246 New theta arrived: [0.3736152  0.95070093], for cost: 0.07210026240041213
# Iter: 247 New theta arrived: [0.37361146 0.95070088], for cost: 0.07209886339053502
# Iter: 248 New theta arrived: [0.37360772 0.95070082], for cost: 0.07209746440863325
# Iter: 249 New theta arrived: [0.37360398 0.95070077], for cost: 0.07209606545470583
# Iter: 250 New theta arrived: [0.37360024 0.95070071], for cost: 0.0720946665287523
# Iter: 251 New theta arrived: [0.37359651 0.95070066], for cost: 0.07209326763077273
# Iter: 252 New theta arrived: [0.37359277 0.9507006 ], for cost: 0.07209186876076566
# Iter: 253 New theta arrived: [0.37358903 0.95070055], for cost: 0.07209046991873076
# Iter: 254 New theta arrived: [0.37358529 0.9507005 ], for cost: 0.07208907110466777
# Iter: 255 New theta arrived: [0.37358155 0.95070044], for cost: 0.07208767231857592
# Iter: 256 New theta arrived: [0.37357781 0.95070039], for cost: 0.07208627356045466
# Iter: 257 New theta arrived: [0.37357407 0.95070033], for cost: 0.07208487483030407
# Iter: 258 New theta arrived: [0.37357033 0.95070028], for cost: 0.07208347612812238
# Iter: 259 New theta arrived: [0.37356659 0.95070023], for cost: 0.0720820774539094
# Iter: 260 New theta arrived: [0.37356285 0.95070017], for cost: 0.07208067880766514
# Iter: 261 New theta arrived: [0.37355911 0.95070012], for cost: 0.07207928018938874
# Iter: 262 New theta arrived: [0.37355537 0.95070006], for cost: 0.07207788159907952
# Iter: 263 New theta arrived: [0.37355163 0.95070001], for cost: 0.07207648303673722
# Iter: 264 New theta arrived: [0.37354789 0.95069995], for cost: 0.07207508450236116
# Iter: 265 New theta arrived: [0.37354415 0.9506999 ], for cost: 0.07207368599595038
# Iter: 266 New theta arrived: [0.37354041 0.95069985], for cost: 0.07207228751750462
# Iter: 267 New theta arrived: [0.37353667 0.95069979], for cost: 0.07207088906702332
# Iter: 268 New theta arrived: [0.37353293 0.95069974], for cost: 0.07206949064450624
# Iter: 269 New theta arrived: [0.3735292  0.95069968], for cost: 0.07206809224995211
# Iter: 270 New theta arrived: [0.37352546 0.95069963], for cost: 0.07206669388336114
# Iter: 271 New theta arrived: [0.37352172 0.95069958], for cost: 0.07206529554473207
# Iter: 272 New theta arrived: [0.37351798 0.95069952], for cost: 0.07206389723406498
# Iter: 273 New theta arrived: [0.37351424 0.95069947], for cost: 0.072062498951359
# Iter: 274 New theta arrived: [0.3735105  0.95069941], for cost: 0.07206110069661359
# Iter: 275 New theta arrived: [0.37350676 0.95069936], for cost: 0.07205970246982796
# Iter: 276 New theta arrived: [0.37350302 0.9506993 ], for cost: 0.07205830427100184
# Iter: 277 New theta arrived: [0.37349928 0.95069925], for cost: 0.0720569061001348
# Iter: 278 New theta arrived: [0.37349554 0.9506992 ], for cost: 0.072055507957226
# Iter: 279 New theta arrived: [0.37349181 0.95069914], for cost: 0.07205410984227499
# Iter: 280 New theta arrived: [0.37348807 0.95069909], for cost: 0.07205271175528104
# Iter: 281 New theta arrived: [0.37348433 0.95069903], for cost: 0.07205131369624385
# Iter: 282 New theta arrived: [0.37348059 0.95069898], for cost: 0.07204991566516288
# Iter: 283 New theta arrived: [0.37347685 0.95069893], for cost: 0.07204851766203707
# Iter: 284 New theta arrived: [0.37347311 0.95069887], for cost: 0.07204711968686645
# Iter: 285 New theta arrived: [0.37346937 0.95069882], for cost: 0.07204572173965015
# Iter: 286 New theta arrived: [0.37346564 0.95069876], for cost: 0.07204432382038761
# Iter: 287 New theta arrived: [0.3734619  0.95069871], for cost: 0.07204292592907864
# Iter: 288 New theta arrived: [0.37345816 0.95069865], for cost: 0.07204152806572255
# Iter: 289 New theta arrived: [0.37345442 0.9506986 ], for cost: 0.07204013023031822
# Iter: 290 New theta arrived: [0.37345068 0.95069855], for cost: 0.07203873242286589
# Iter: 291 New theta arrived: [0.37344694 0.95069849], for cost: 0.07203733464336433
# Iter: 292 New theta arrived: [0.37344321 0.95069844], for cost: 0.07203593689181313
# Iter: 293 New theta arrived: [0.37343947 0.95069838], for cost: 0.0720345391682122
# Iter: 294 New theta arrived: [0.37343573 0.95069833], for cost: 0.07203314147256046
# Iter: 295 New theta arrived: [0.37343199 0.95069828], for cost: 0.0720317438048576
# Iter: 296 New theta arrived: [0.37342825 0.95069822], for cost: 0.0720303461651032
# Iter: 297 New theta arrived: [0.37342451 0.95069817], for cost: 0.07202894855329622
# Iter: 298 New theta arrived: [0.37342078 0.95069811], for cost: 0.07202755096943643
# Iter: 299 New theta arrived: [0.37341704 0.95069806], for cost: 0.07202615341352328
# Iter: 300 New theta arrived: [0.3734133  0.95069801], for cost: 0.07202475588555618
# Iter: 301 New theta arrived: [0.37340956 0.95069795], for cost: 0.07202335838553459
# Iter: 302 New theta arrived: [0.37340582 0.9506979 ], for cost: 0.07202196091345783
# Iter: 303 New theta arrived: [0.37340209 0.95069784], for cost: 0.07202056346932541
# Iter: 304 New theta arrived: [0.37339835 0.95069779], for cost: 0.07201916605313691
# Iter: 305 New theta arrived: [0.37339461 0.95069773], for cost: 0.07201776866489126
# Iter: 306 New theta arrived: [0.37339087 0.95069768], for cost: 0.07201637130458884
# Iter: 307 New theta arrived: [0.37338714 0.95069763], for cost: 0.0720149739722279
# Iter: 308 New theta arrived: [0.3733834  0.95069757], for cost: 0.07201357666780894
# Iter: 309 New theta arrived: [0.37337966 0.95069752], for cost: 0.07201217939133106
# Iter: 310 New theta arrived: [0.37337592 0.95069746], for cost: 0.07201078214279345
# Iter: 311 New theta arrived: [0.37337219 0.95069741], for cost: 0.0720093849221956
# Iter: 312 New theta arrived: [0.37336845 0.95069736], for cost: 0.07200798772953733
# Iter: 313 New theta arrived: [0.37336471 0.9506973 ], for cost: 0.07200659056481738
# Iter: 314 New theta arrived: [0.37336097 0.95069725], for cost: 0.07200519342803617
# Iter: 315 New theta arrived: [0.37335724 0.95069719], for cost: 0.07200379631919225
# Iter: 316 New theta arrived: [0.3733535  0.95069714], for cost: 0.07200239923828568
# Iter: 317 New theta arrived: [0.37334976 0.95069708], for cost: 0.07200100218531545
# Iter: 318 New theta arrived: [0.37334602 0.95069703], for cost: 0.07199960516028117
# Iter: 319 New theta arrived: [0.37334229 0.95069698], for cost: 0.07199820816318231
# Iter: 320 New theta arrived: [0.37333855 0.95069692], for cost: 0.0719968111940183
# Iter: 321 New theta arrived: [0.37333481 0.95069687], for cost: 0.07199541425278852
# Iter: 322 New theta arrived: [0.37333107 0.95069681], for cost: 0.07199401733949289
# Iter: 323 New theta arrived: [0.37332734 0.95069676], for cost: 0.07199262045413025
# Iter: 324 New theta arrived: [0.3733236  0.95069671], for cost: 0.07199122359669989
# Iter: 325 New theta arrived: [0.37331986 0.95069665], for cost: 0.07198982676720188
# Iter: 326 New theta arrived: [0.37331613 0.9506966 ], for cost: 0.07198842996563522
# Iter: 327 New theta arrived: [0.37331239 0.95069654], for cost: 0.0719870331919995
# Iter: 328 New theta arrived: [0.37330865 0.95069649], for cost: 0.07198563644629417
# Iter: 329 New theta arrived: [0.37330492 0.95069643], for cost: 0.07198423972851888
# Iter: 330 New theta arrived: [0.37330118 0.95069638], for cost: 0.07198284303867263
# Iter: 331 New theta arrived: [0.37329744 0.95069633], for cost: 0.07198144637675527
# Iter: 332 New theta arrived: [0.37329371 0.95069627], for cost: 0.07198004974276591
# Iter: 333 New theta arrived: [0.37328997 0.95069622], for cost: 0.07197865313670383
# Iter: 334 New theta arrived: [0.37328623 0.95069616], for cost: 0.07197725655856932
# Iter: 335 New theta arrived: [0.3732825  0.95069611], for cost: 0.07197586000836094
# Iter: 336 New theta arrived: [0.37327876 0.95069606], for cost: 0.07197446348607879
# Iter: 337 New theta arrived: [0.37327502 0.950696  ], for cost: 0.0719730669917218
# Iter: 338 New theta arrived: [0.37327129 0.95069595], for cost: 0.07197167052528945
# Iter: 339 New theta arrived: [0.37326755 0.95069589], for cost: 0.07197027408678155
# Iter: 340 New theta arrived: [0.37326381 0.95069584], for cost: 0.07196887767619718
# Iter: 341 New theta arrived: [0.37326008 0.95069578], for cost: 0.07196748129353611
# Iter: 342 New theta arrived: [0.37325634 0.95069573], for cost: 0.07196608493879733
# Iter: 343 New theta arrived: [0.3732526  0.95069568], for cost: 0.07196468861198074
# Iter: 344 New theta arrived: [0.37324887 0.95069562], for cost: 0.07196329231308558
# Iter: 345 New theta arrived: [0.37324513 0.95069557], for cost: 0.0719618960421116
# Iter: 346 New theta arrived: [0.37324139 0.95069551], for cost: 0.07196049979905772
# Iter: 347 New theta arrived: [0.37323766 0.95069546], for cost: 0.07195910358392321
# Iter: 348 New theta arrived: [0.37323392 0.95069541], for cost: 0.07195770739670837
# Iter: 349 New theta arrived: [0.37323019 0.95069535], for cost: 0.07195631123741199
# Iter: 350 New theta arrived: [0.37322645 0.9506953 ], for cost: 0.07195491510603377
# Iter: 351 New theta arrived: [0.37322271 0.95069524], for cost: 0.07195351900257321
# Iter: 352 New theta arrived: [0.37321898 0.95069519], for cost: 0.07195212292702935
# Iter: 353 New theta arrived: [0.37321524 0.95069514], for cost: 0.07195072687940203
# Iter: 354 New theta arrived: [0.37321151 0.95069508], for cost: 0.07194933085969071
# Iter: 355 New theta arrived: [0.37320777 0.95069503], for cost: 0.07194793486789457
# Iter: 356 New theta arrived: [0.37320403 0.95069497], for cost: 0.0719465389040131
# Iter: 357 New theta arrived: [0.3732003  0.95069492], for cost: 0.07194514296804616
# Iter: 358 New theta arrived: [0.37319656 0.95069486], for cost: 0.07194374705999249
# Iter: 359 New theta arrived: [0.37319283 0.95069481], for cost: 0.07194235117985225
# Iter: 360 New theta arrived: [0.37318909 0.95069476], for cost: 0.07194095532762418
# Iter: 361 New theta arrived: [0.37318536 0.9506947 ], for cost: 0.07193955950330812
# Iter: 362 New theta arrived: [0.37318162 0.95069465], for cost: 0.07193816370690351
# Iter: 363 New theta arrived: [0.37317788 0.95069459], for cost: 0.07193676793840946
# Iter: 364 New theta arrived: [0.37317415 0.95069454], for cost: 0.07193537219782649
# Iter: 365 New theta arrived: [0.37317041 0.95069449], for cost: 0.07193397648515228
# Iter: 366 New theta arrived: [0.37316668 0.95069443], for cost: 0.07193258080038754
# Iter: 367 New theta arrived: [0.37316294 0.95069438], for cost: 0.07193118514353171
# Iter: 368 New theta arrived: [0.37315921 0.95069432], for cost: 0.0719297895145839
# Iter: 369 New theta arrived: [0.37315547 0.95069427], for cost: 0.07192839391354328
# Iter: 370 New theta arrived: [0.37315174 0.95069421], for cost: 0.0719269983404095
# Iter: 371 New theta arrived: [0.373148   0.95069416], for cost: 0.07192560279518237
# Iter: 372 New theta arrived: [0.37314426 0.95069411], for cost: 0.07192420727786107
# Iter: 373 New theta arrived: [0.37314053 0.95069405], for cost: 0.07192281178844488
# Iter: 374 New theta arrived: [0.37313679 0.950694  ], for cost: 0.07192141632693369
# Iter: 375 New theta arrived: [0.37313306 0.95069394], for cost: 0.07192002089332618
# Iter: 376 New theta arrived: [0.37312932 0.95069389], for cost: 0.07191862548762233
# Iter: 377 New theta arrived: [0.37312559 0.95069384], for cost: 0.07191723010982147
# Iter: 378 New theta arrived: [0.37312185 0.95069378], for cost: 0.07191583475992351
# Iter: 379 New theta arrived: [0.37311812 0.95069373], for cost: 0.07191443943792704
# Iter: 380 New theta arrived: [0.37311438 0.95069367], for cost: 0.07191304414383194
# Iter: 381 New theta arrived: [0.37311065 0.95069362], for cost: 0.07191164887763801
# Iter: 382 New theta arrived: [0.37310691 0.95069356], for cost: 0.07191025363934372
# Iter: 383 New theta arrived: [0.37310318 0.95069351], for cost: 0.07190885842894972
# Iter: 384 New theta arrived: [0.37309944 0.95069346], for cost: 0.0719074632464546
# Iter: 385 New theta arrived: [0.37309571 0.9506934 ], for cost: 0.07190606809185808
# Iter: 386 New theta arrived: [0.37309197 0.95069335], for cost: 0.07190467296515937
# Iter: 387 New theta arrived: [0.37308824 0.95069329], for cost: 0.07190327786635822
# Iter: 388 New theta arrived: [0.37308451 0.95069324], for cost: 0.07190188279545374
# Iter: 389 New theta arrived: [0.37308077 0.95069319], for cost: 0.071900487752446
# Iter: 390 New theta arrived: [0.37307704 0.95069313], for cost: 0.07189909273733379
# Iter: 391 New theta arrived: [0.3730733  0.95069308], for cost: 0.07189769775011665
# Iter: 392 New theta arrived: [0.37306957 0.95069302], for cost: 0.07189630279079451
# Iter: 393 New theta arrived: [0.37306583 0.95069297], for cost: 0.07189490785936618
# Iter: 394 New theta arrived: [0.3730621  0.95069292], for cost: 0.07189351295583177
# Iter: 395 New theta arrived: [0.37305836 0.95069286], for cost: 0.07189211808018997
# Iter: 396 New theta arrived: [0.37305463 0.95069281], for cost: 0.07189072323244045
# Iter: 397 New theta arrived: [0.3730509  0.95069275], for cost: 0.0718893284125829
# Iter: 398 New theta arrived: [0.37304716 0.9506927 ], for cost: 0.07188793362061713
# Iter: 399 New theta arrived: [0.37304343 0.95069264], for cost: 0.07188653885654162
# Iter: 400 New theta arrived: [0.37303969 0.95069259], for cost: 0.0718851441203563
# Iter: 401 New theta arrived: [0.37303596 0.95069254], for cost: 0.07188374941206103
# Iter: 402 New theta arrived: [0.37303222 0.95069248], for cost: 0.07188235473165426
# Iter: 403 New theta arrived: [0.37302849 0.95069243], for cost: 0.07188096007913661
# Iter: 404 New theta arrived: [0.37302476 0.95069237], for cost: 0.07187956545450633
# Iter: 405 New theta arrived: [0.37302102 0.95069232], for cost: 0.07187817085776364
# Iter: 406 New theta arrived: [0.37301729 0.95069227], for cost: 0.07187677628890807
# Iter: 407 New theta arrived: [0.37301355 0.95069221], for cost: 0.07187538174793849
# Iter: 408 New theta arrived: [0.37300982 0.95069216], for cost: 0.07187398723485493
# Iter: 409 New theta arrived: [0.37300609 0.9506921 ], for cost: 0.07187259274965618
# Iter: 410 New theta arrived: [0.37300235 0.95069205], for cost: 0.07187119829234251
# Iter: 411 New theta arrived: [0.37299862 0.95069199], for cost: 0.07186980386291252
# Iter: 412 New theta arrived: [0.37299488 0.95069194], for cost: 0.07186840946136583
# Iter: 413 New theta arrived: [0.37299115 0.95069189], for cost: 0.0718670150877023
# Iter: 414 New theta arrived: [0.37298742 0.95069183], for cost: 0.07186562074192136
# Iter: 415 New theta arrived: [0.37298368 0.95069178], for cost: 0.07186422642402193
# Iter: 416 New theta arrived: [0.37297995 0.95069172], for cost: 0.07186283213400411
# Iter: 417 New theta arrived: [0.37297622 0.95069167], for cost: 0.07186143787186701
# Iter: 418 New theta arrived: [0.37297248 0.95069162], for cost: 0.07186004363760977
# Iter: 419 New theta arrived: [0.37296875 0.95069156], for cost: 0.07185864943123213
# Iter: 420 New theta arrived: [0.37296502 0.95069151], for cost: 0.0718572552527337
# Iter: 421 New theta arrived: [0.37296128 0.95069145], for cost: 0.0718558611021134
# Iter: 422 New theta arrived: [0.37295755 0.9506914 ], for cost: 0.07185446697937128
# Iter: 423 New theta arrived: [0.37295382 0.95069134], for cost: 0.07185307288450689
# Iter: 424 New theta arrived: [0.37295008 0.95069129], for cost: 0.0718516788175185
# Iter: 425 New theta arrived: [0.37294635 0.95069124], for cost: 0.07185028477840728
# Iter: 426 New theta arrived: [0.37294262 0.95069118], for cost: 0.07184889076717103
# Iter: 427 New theta arrived: [0.37293888 0.95069113], for cost: 0.07184749678381026
# Iter: 428 New theta arrived: [0.37293515 0.95069107], for cost: 0.07184610282832385
# Iter: 429 New theta arrived: [0.37293142 0.95069102], for cost: 0.07184470890071143
# Iter: 430 New theta arrived: [0.37292768 0.95069097], for cost: 0.0718433150009727
# Iter: 431 New theta arrived: [0.37292395 0.95069091], for cost: 0.07184192112910681
# Iter: 432 New theta arrived: [0.37292022 0.95069086], for cost: 0.07184052728511323
# Iter: 433 New theta arrived: [0.37291648 0.9506908 ], for cost: 0.0718391334689914
# Iter: 434 New theta arrived: [0.37291275 0.95069075], for cost: 0.0718377396807412
# Iter: 435 New theta arrived: [0.37290902 0.9506907 ], for cost: 0.07183634592036117
# Iter: 436 New theta arrived: [0.37290528 0.95069064], for cost: 0.07183495218785134
# Iter: 437 New theta arrived: [0.37290155 0.95069059], for cost: 0.07183355848321103
# Iter: 438 New theta arrived: [0.37289782 0.95069053], for cost: 0.07183216480643982
# Iter: 439 New theta arrived: [0.37289409 0.95069048], for cost: 0.07183077115753707
# Iter: 440 New theta arrived: [0.37289035 0.95069042], for cost: 0.07182937753650222
# Iter: 441 New theta arrived: [0.37288662 0.95069037], for cost: 0.07182798394333478
# Iter: 442 New theta arrived: [0.37288289 0.95069032], for cost: 0.07182659037803374
# Iter: 443 New theta arrived: [0.37287916 0.95069026], for cost: 0.07182519684059953
# Iter: 444 New theta arrived: [0.37287542 0.95069021], for cost: 0.07182380333103056
# Iter: 445 New theta arrived: [0.37287169 0.95069015], for cost: 0.07182240984932674
# Iter: 446 New theta arrived: [0.37286796 0.9506901 ], for cost: 0.07182101639548742
# Iter: 447 New theta arrived: [0.37286423 0.95069005], for cost: 0.07181962296951243
# Iter: 448 New theta arrived: [0.37286049 0.95068999], for cost: 0.07181822957140033
# Iter: 449 New theta arrived: [0.37285676 0.95068994], for cost: 0.07181683620115152
# Iter: 450 New theta arrived: [0.37285303 0.95068988], for cost: 0.0718154428587645
# Iter: 451 New theta arrived: [0.3728493  0.95068983], for cost: 0.07181404954423988
# Iter: 452 New theta arrived: [0.37284556 0.95068977], for cost: 0.07181265625757605
# Iter: 453 New theta arrived: [0.37284183 0.95068972], for cost: 0.07181126299877287
# Iter: 454 New theta arrived: [0.3728381  0.95068967], for cost: 0.07180986976782963
# Iter: 455 New theta arrived: [0.37283437 0.95068961], for cost: 0.07180847656474634
# Iter: 456 New theta arrived: [0.37283063 0.95068956], for cost: 0.0718070833895221
# Iter: 457 New theta arrived: [0.3728269 0.9506895], for cost: 0.0718056902421559
# Iter: 458 New theta arrived: [0.37282317 0.95068945], for cost: 0.07180429712264758
# Iter: 459 New theta arrived: [0.37281944 0.9506894 ], for cost: 0.07180290403099676
# Iter: 460 New theta arrived: [0.37281571 0.95068934], for cost: 0.0718015109672029
# Iter: 461 New theta arrived: [0.37281197 0.95068929], for cost: 0.07180011793126459
# Iter: 462 New theta arrived: [0.37280824 0.95068923], for cost: 0.07179872492318244
# Iter: 463 New theta arrived: [0.37280451 0.95068918], for cost: 0.07179733194295515
# Iter: 464 New theta arrived: [0.37280078 0.95068912], for cost: 0.07179593899058229
# Iter: 465 New theta arrived: [0.37279705 0.95068907], for cost: 0.07179454606606338
# Iter: 466 New theta arrived: [0.37279332 0.95068902], for cost: 0.07179315316939798
# Iter: 467 New theta arrived: [0.37278958 0.95068896], for cost: 0.0717917603005853
# Iter: 468 New theta arrived: [0.37278585 0.95068891], for cost: 0.07179036745962496
# Iter: 469 New theta arrived: [0.37278212 0.95068885], for cost: 0.07178897464651635
# Iter: 470 New theta arrived: [0.37277839 0.9506888 ], for cost: 0.07178758186125891
# Iter: 471 New theta arrived: [0.37277466 0.95068875], for cost: 0.07178618910385236
# Iter: 472 New theta arrived: [0.37277093 0.95068869], for cost: 0.07178479637429545
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 alpha_dict = find_best_alpha(X_train, y_train, X_val, y_val, iterations)
#
# File ~/Documents/code/idc/sem4/machine-learning-for-data/hw1/hw1.py:202, in find_best_alpha(X_train, y_train, X_val, y_val, iterations)
#     200     if debug:
#     201         print(f"Trying alpha: {alpha}")
# --> 202     theta, _= efficient_gradient_descent(
#     203         X=X_train,
#     204         y=y_train,
#     205         theta=init_theta,
#     206         alpha=alpha,
#     207         num_iters=iterations,
#     208     )
#     210     alpha_dict[alpha] = compute_cost(X_val, y_val, theta)
#     212 return alpha_dict
#
# File ~/Documents/code/idc/sem4/machine-learning-for-data/hw1/hw1.py:175, in efficient_gradient_descent(X, y, theta, alpha, num_iters)
#     156 def efficient_gradient_descent(X, y, theta, alpha, num_iters):
#     157     """
#     158     Learn the parameters of your model using the training set, but stop
#     159     the learning process once the improvement of the loss value is smaller
#    (...)
#     172     - J_history: the loss value for every iteration.
#     173     """
# --> 175     return gradient_descent(X, y, theta, alpha, num_iters, stop=True)
#
# File ~/Documents/code/idc/sem4/machine-learning-for-data/hw1/hw1.py:104, in gradient_descent(X, y, theta, alpha, num_iters, stop)
#     102 theta_temps = []
#     103 for j in range(len(theta)):
# --> 104     partial_deriv = _compute_partial_derivative(X, y, theta, j)
#     105     theta_temps.append(theta[j] - alpha*partial_deriv)
#     107 # update theta
#
# File ~/Documents/code/idc/sem4/machine-learning-for-data/hw1/hw1.py:131, in _compute_partial_derivative(X, y, theta, _by_j)
#     129     for j in range(len(theta)): # dim agnostic method
#     130         temp+=theta[j]*(X[i][j])
# --> 131     sum+=(temp-y[i])*(X[i][_by_j])
#     133 return sum / m
#
# KeyboardInterrupt:

# %% [markdown]
# We can now obtain the best learning rate from the dictionary `alpha_dict` in a single line.

# %%
best_alpha = min(alpha_dict, key=alpha_dict.get)

# %%
print(best_alpha)
# Out:
# 1

# %% [markdown]
# The following code gets the best three alpha values you just calculated and provides a graph with three lines indicating the training loss as a function of iterations. Use it as a test for your implementation. You can change this code as you see fit.

# %%
top_3_alphas = sorted([(value, key) for key, value in alpha_dict.items()], reverse=False)[:3]
top_3_alphas = [x[1] for x in top_3_alphas]

histories = []
for alpha in top_3_alphas:
    params = np.random.random(size=2)
    _, J_history = gradient_descent(X_train ,y_train, params, alpha, iterations)
    histories.append(J_history)

for i, (alpha, color) in enumerate(zip(top_3_alphas, ['b','g','r'])):
    plt.plot(np.arange(iterations), histories[i], color, label='alpha='+str(alpha))

plt.xscale('log')
plt.ylim(0, 0.005)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations')
plt.legend()
plt.show()

# %% [markdown]
# This is yet another check. This function plots the regression lines of your model and the model based on the pseudoinverse calculation. Both models should exhibit the same trend through the data.

# %%
plt.figure(figsize=(7, 7))
plt.plot(X_train[:,1], y_train, 'ro', ms=1, mec='k')
plt.ylabel('Price in USD')
plt.xlabel('sq.ft')
plt.plot(X_train[:, 1], np.dot(X_train, theta), 'o')
plt.plot(X_train[:, 1], np.dot(X_train, theta_pinv), '-')

plt.legend(['Training data', 'Linear regression', 'Best theta']);

# %% [markdown]
# ## Part 2: Multivariate Linear Regression
#
# In most cases, you will deal with datasets that have more than one feature. It can be as little as two features and up to thousands of features. In those cases, we use a multivariate linear regression model. The regression equation is almost the same as the simple linear regression equation:
#
# $$
# \hat{y} = h_\theta(\vec{x}) = \theta^T \vec{x} = \theta_0 + \theta_1 x_1 + ... + \theta_n x_n
# $$
#
#
# If you wrote proper vectorized code, this part should be trivial and work without changes. If this is not the case, you should go back and edit your functions such that they support both multivariate and single variable regression. **Your code should not check the dimensionality of the input before running**.

# %%
# Read comma separated data
df = pd.read_csv('data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  yr_built  \
# 0      5650     1.0           0     0          3      7        1180      1955
# 1      7242     2.0           0     0          3      7        2170      1951
# 2     10000     1.0           0     0          3      6         770      1933
# 3      5000     1.0           0     0          5      7        1050      1965
# 4      8080     1.0           0     0          3      8        1680      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# ## Preprocessing
#
# Like in the single variable case, we need to create a numpy array from the dataframe. Before doing so, we should notice that some of the features are clearly irrelevant so we will go ahead and drop them.

# %%
X = df.drop(columns=['price', 'id', 'date']).values
y = df['price'].values

# %% [markdown]
# Use the same `preprocess` function you implemented previously. Notice that proper vectorized implementation should work regardless of the dimensionality of the input. You might want to check that your code in the previous parts still works.

# %%
# preprocessing
X, y = preprocess(X, y)

# %%
# training and validation split 
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train,:], X[idx_val,:]
y_train, y_val = y[idx_train], y[idx_val]

# %% [markdown]
# Using 3D visualization, we can still observe trends in the data. Visualizing additional dimensions requires advanced techniques we will learn later in the course.

# %%
# %matplotlib inline
import mpl_toolkits.mplot3d.axes3d as p3
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')
xx = X_train[:, 1][:1000]
yy = X_train[:, 2][:1000]
zz = y_train[:1000]
ax.scatter(xx, yy, zz, marker='o')
ax.set_xlabel('bathrooms')
ax.set_ylabel('sqft_living')
ax.set_zlabel('price')
plt.show()

# %% [markdown]
# Make sure the functions `apply_bias_trick`, `compute_cost`, `gradient_descent`, `efficient_gradient_descent` and `compute_pinv` work on the multi-dimensional dataset. If you make any changes, make sure your code still works on the single variable regression model.

# %%
# bias trick
X_train = apply_bias_trick(X_train)
X_val = apply_bias_trick(X_val)

X_train.shape, X_val.shape
# Out:
# ((4000, 18), (1000, 18))

# %%
# calculating the cost
shape = X_train.shape[1]
theta = np.ones(shape)
J = compute_cost(X_train, y_train, theta)

# %%
from hw1 import set_debug
set_debug(True)

# %%
# running the efficient version of gradient descent
np.random.seed(42)
shape = X_train.shape[1] 
theta = np.random.random(shape)
theta, J_history = efficient_gradient_descent(X_train ,y_train, theta, best_alpha, iterations)
# Out:
# theta [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864 0.15599452
#   2.67054116e-02 -7.46839583e-03], for cost: 0.00047195354174070633
# Iter: 1086 New theta arrived: [ 2.12133114e-04 -5.08936202e-02  1.84848131e-02  2.55267854e-01
#   1.25687777e-02  5.23960437e-03  1.16376838e-01  2.57972351e-02
#   1.07424646e-02  1.45303057e-01 -1.86613105e-03 -4.84833699e-02
#   3.88501691e-03 -1.70248098e-02  5.01536406e-02 -3.07225520e-02
#   2.67014778e-02 -7.52969186e-03], for cost: 0.000471943397475214
# Iter: 1087 New theta arrived: [ 2.12137482e-04 -5.09189012e-02  1.84878975e-02  2.55278794e-01
#   1.25509392e-02  5.23089638e-03  1.16372250e-01  2.57998029e-02
#   1.07441889e-02  1.45263336e-01 -1.80645131e-03 -4.84810243e-02
#   3.88621142e-03 -1.70245521e-02  5.01554654e-02 -3.07193113e-02
#   2.66975492e-02 -7.59080655e-03], for cost: 0.00047193330722776673
# Iter: 1088 New theta arrived: [ 2.12141829e-04 -5.09441023e-02  1.84909731e-02  2.55289674e-01
#   1.25331486e-02  5.22220890e-03  1.16367669e-01  2.58023675e-02
#   1.07459094e-02  1.45223718e-01 -1.74690359e-03 -4.84786837e-02
#   3.88740315e-03 -1.70242950e-02  5.01572869e-02 -3.07160824e-02
#   2.66936259e-02 -7.65174044e-03], for cost: 0.00047192327070157066
# Iter: 1089 New theta arrived: [ 2.12146157e-04 -5.09692236e-02  1.84940401e-02  2.55300494e-01
#   1.25154058e-02  5.21354187e-03  1.16363096e-01  2.58049289e-02
#   1.07476264e-02  1.45184205e-01 -1.68748759e-03 -4.84763482e-02
#   3.88859209e-03 -1.70240384e-02  5.01591051e-02 -3.07128653e-02
#   2.66897079e-02 -7.71249407e-03], for cost: 0.00047191328760147813

# %%
# calculating the pseudoinverse
theta_pinv = compute_pinv(X_train ,y_train)
J_pinv = compute_cost(X_train, y_train, theta_pinv)

# %% [markdown]
# We can use visualization to make sure the code works well. Notice we use logarithmic scale for the number of iterations, since gradient descent converges after ~500 iterations.

# %%
plt.plot(np.arange(len(J_history)), J_history)
plt.xscale('log')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss as a function of iterations - multivariate linear regression')
plt.hlines(y = J_pinv, xmin = 0, xmax = len(J_history), color='r',
           linewidth = 1, linestyle = 'dashed')
plt.show()

# %% [markdown]
# ## Part 3: Forward feature selection (15 points)
#
# Adding additional features to our regression model makes it more complicated but does not necessarily improves performance.
#
# Forward feature selection is a greedy, iterative algorithm used to select the most relevant features for a predictive model. The objective of this algorithm is to improve the model's performance by identifying and using only the most relevant features, potentially reducing overfitting, improving accuracy, and reducing computational cost.
#
# Implement forward feature selection using the following guidelines:
# 1. Start with an empty set of selected features.
# 1. For each feature not yet in the selected set, do the following:
#     1. Add the feature to the selected set temporarily.
#     1. Train a model using the current set of selected features and evaluate its performance by calculating the cost or error on a validation set.
#     1. Remove the temporarily added feature from the selected set.
# 1. Choose the feature that resulted in the best model performance and permanently add it to the selected set.
# 1. Repeat steps 2-3 until you have 5 features (not including the bias).
#
# ---
# Open `hw1.py` and complete the function `forward_feature_selection`.
#
# **Note that you should use the inputs as provided in the next cell and don't forget to use the bias trick inside `forward_feature_selection`**.

# %%
df = pd.read_csv('data.csv')
feature_names = df.drop(columns=['price', 'id', 'date']).columns.values
X = df.drop(columns=['price', 'id', 'date']).values
y = df['price'].values

# %%
df = pd.read_csv('data.csv')
feature_names = df.drop(columns=['price', 'id', 'date']).columns.values
X = df.drop(columns=['price', 'id', 'date']).values
y = df['price'].values

# preprocessing
X, y = preprocess(X, y)

# training and validation split
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train,:], X[idx_val,:]
y_train, y_val = y[idx_train], y[idx_val]

# %%
from hw1 import forward_feature_selection

# %%
ffs = forward_feature_selection(X_train, y_train, X_val, y_val, best_alpha, iterations)
for feature in ffs:
    print(feature_names[feature])
# Out:
# sqft_living
# lat
# waterfront
# grade
# yr_built

# %% [markdown]
# ## Part 4: Polynomial regression (15 points)
#
# Implement a function to create polynomial features up to a degree of 2 for given dataset. The function should take a pandas DataFrame as input and should return a new DataFrame with all possible square features, including the original features. When you create the new dataframe, make sure the feature names also represent the transformation performed. For example: `sqft_lot`, `yr_built^2`, `bedrooms*bathrooms`, ...
#
# After you obtain the polynomial dataframe, use forward feature selection and print the 5 best features.
#
# Open `hw1.py` and complete the function `create_square_features`.

# %%
from hw1 import create_square_features

# %%
df = pd.read_csv('data.csv')

y = df['price'].values
df = df.drop(columns=['price', 'id', 'date'])
df = df.astype('float64')
df_poly = create_square_features(df)
X = df_poly.values
X.shape, y.shape
# Out:
# ((5000, 170), (5000,))

# %%
# preprocessing
X, y = preprocess(X, y)

# %%
# training and validation split
np.random.seed(42)
indices = np.random.permutation(X.shape[0])
idx_train, idx_val = indices[:int(0.8*X.shape[0])], indices[int(0.8*X.shape[0]):]
X_train, X_val = X[idx_train,:], X[idx_val,:]
y_train, y_val = y[idx_train], y[idx_val]

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((4000, 170), (1000, 170), (4000,), (1000,))

# %%
feature_names = df_poly.columns.values

# %%
ffs = forward_feature_selection(X_train, y_train, X_val, y_val, 1, 40000)
# Out:
# Considering feature: 0
# Considering feature set: [0]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 1
# Considering feature set: [1]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# found new min cost for 1 features:
#                                 old min_cost 0.0012882907771249138, new min_cost: 0.0009867979911248486. diff = 0.00030149278600006516
#                                 old selected_features [0], new selected_features: [1]
# Considering feature: 2
# Considering feature set: [2]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# found new min cost for 1 features:
#                                 old min_cost 0.0009867979911248486, new min_cost: 0.0007074118603530308. diff = 0.0002793861307718178
#                                 old selected_features [1], new selected_features: [2]
# Considering feature: 3
# Considering feature set: [3]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Considering feature: 4
# Considering feature set: [4]
# Iteration num 0
# Iteration num 100
# Considering feature: 5
# Considering feature set: [5]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 6
# Considering feature set: [6]
# Iteration num 0
# Considering feature: 7
# Considering feature set: [7]
# Iteration num 0
# Iteration num 100
# Considering feature: 8
# Considering feature set: [8]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 9
# Considering feature set: [9]
# Iteration num 0
# Considering feature: 10
# Considering feature set: [10]
# Iteration num 0
# Considering feature: 11
# Considering feature set: [11]
# Iteration num 0
# Iteration num 100
# Considering feature: 12
# Considering feature set: [12]
# Iteration num 0
# Considering feature: 13
# Considering feature set: [13]
# Iteration num 0
# Iteration num 100
# Considering feature: 14
# Considering feature set: [14]
# Iteration num 0
# Iteration num 100
# Considering feature: 15
# Considering feature set: [15]
# Iteration num 0
# Iteration num 100
# Considering feature: 16
# Considering feature set: [16]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 17
# Considering feature set: [17]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 18
# Considering feature set: [18]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 19
# Considering feature set: [19]
# Iteration num 0
# Iteration num 100
# Considering feature: 20
# Considering feature set: [20]
# Iteration num 0
# Considering feature: 21
# Considering feature set: [21]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 22
# Considering feature set: [22]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 23
# Considering feature set: [23]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 24
# Considering feature set: [24]
# Iteration num 0
# Iteration num 100
# Considering feature: 25
# Considering feature set: [25]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 26
# Considering feature set: [26]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 27
# Considering feature set: [27]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 28
# Considering feature set: [28]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 29
# Considering feature set: [29]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 30
# Considering feature set: [30]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 31
# Considering feature set: [31]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 32
# Considering feature set: [32]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 33
# Considering feature set: [33]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 34
# Considering feature set: [34]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 35
# Considering feature set: [35]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# found new min cost for 1 features:
#                                 old min_cost 0.0007074118603530308, new min_cost: 0.0006640909309379241. diff = 4.332092941510674e-05
#                                 old selected_features [2], new selected_features: [35]
# Considering feature: 36
# Considering feature set: [36]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Considering feature: 37
# Considering feature set: [37]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 38
# Considering feature set: [38]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 39
# Considering feature set: [39]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 40
# Considering feature set: [40]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 41
# Considering feature set: [41]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 42
# Considering feature set: [42]
# Iteration num 0
# Iteration num 100
# Considering feature: 43
# Considering feature set: [43]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 44
# Considering feature set: [44]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 45
# Considering feature set: [45]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 46
# Considering feature set: [46]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 47
# Considering feature set: [47]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 48
# Considering feature set: [48]
# Iteration num 0
# Iteration num 100
# Considering feature: 49
# Considering feature set: [49]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 50
# Considering feature set: [50]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# found new min cost for 1 features:
#                                 old min_cost 0.0006640909309379241, new min_cost: 0.000632691258900517. diff = 3.139967203740705e-05
#                                 old selected_features [35], new selected_features: [50]
# Considering feature: 51
# Considering feature set: [51]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 52
# Considering feature set: [52]
# Iteration num 0
# Iteration num 100
# Considering feature: 53
# Considering feature set: [53]
# Iteration num 0
# Considering feature: 54
# Considering feature set: [54]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 55
# Considering feature set: [55]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 56
# Considering feature set: [56]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# found new min cost for 1 features:
#                                 old min_cost 0.000632691258900517, new min_cost: 0.000600610548580326. diff = 3.208071032019099e-05
#                                 old selected_features [50], new selected_features: [56]
# Considering feature: 57
# Considering feature set: [57]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 58
# Considering feature set: [58]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 59
# Considering feature set: [59]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 60
# Considering feature set: [60]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 61
# Considering feature set: [61]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 62
# Considering feature set: [62]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 63
# Considering feature set: [63]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 64
# Considering feature set: [64]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 65
# Considering feature set: [65]
# Iteration num 0
# Considering feature: 66
# Considering feature set: [66]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 67
# Considering feature set: [67]
# Iteration num 0
# Considering feature: 68
# Considering feature set: [68]
# Iteration num 0
# Considering feature: 69
# Considering feature set: [69]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Iteration num 2400
# Iteration num 2500
# Iteration num 2600
# Iteration num 2700
# Considering feature: 70
# Considering feature set: [70]
# Iteration num 0
# Considering feature: 71
# Considering feature set: [71]
# Iteration num 0
# Considering feature: 72
# Considering feature set: [72]
# Iteration num 0
# Considering feature: 73
# Considering feature set: [73]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 74
# Considering feature set: [74]
# Iteration num 0
# Considering feature: 75
# Considering feature set: [75]
# Iteration num 0
# Considering feature: 76
# Considering feature set: [76]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Considering feature: 77
# Considering feature set: [77]
# Iteration num 0
# Considering feature: 78
# Considering feature set: [78]
# Iteration num 0
# Considering feature: 79
# Considering feature set: [79]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 80
# Considering feature set: [80]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 81
# Considering feature set: [81]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 82
# Considering feature set: [82]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 83
# Considering feature set: [83]
# Iteration num 0
# Considering feature: 84
# Considering feature set: [84]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 85
# Considering feature set: [85]
# Iteration num 0
# Considering feature: 86
# Considering feature set: [86]
# Iteration num 0
# Iteration num 100
# Considering feature: 87
# Considering feature set: [87]
# Iteration num 0
# Considering feature: 88
# Considering feature set: [88]
# Iteration num 0
# Iteration num 100
# Considering feature: 89
# Considering feature set: [89]
# Iteration num 0
# Iteration num 100
# Considering feature: 90
# Considering feature set: [90]
# Iteration num 0
# Iteration num 100
# Considering feature: 91
# Considering feature set: [91]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 92
# Considering feature set: [92]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 93
# Considering feature set: [93]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 94
# Considering feature set: [94]
# Iteration num 0
# Considering feature: 95
# Considering feature set: [95]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 96
# Considering feature set: [96]
# Iteration num 0
# Considering feature: 97
# Considering feature set: [97]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 98
# Considering feature set: [98]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 99
# Considering feature set: [99]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 100
# Considering feature set: [100]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 101
# Considering feature set: [101]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 102
# Considering feature set: [102]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 103
# Considering feature set: [103]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 104
# Considering feature set: [104]
# Iteration num 0
# Considering feature: 105
# Considering feature set: [105]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 106
# Considering feature set: [106]
# Iteration num 0
# Iteration num 100
# Considering feature: 107
# Considering feature set: [107]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 108
# Considering feature set: [108]
# Iteration num 0
# Iteration num 100
# Considering feature: 109
# Considering feature set: [109]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 110
# Considering feature set: [110]
# Iteration num 0
# Iteration num 100
# Considering feature: 111
# Considering feature set: [111]
# Iteration num 0
# Iteration num 100
# Considering feature: 112
# Considering feature set: [112]
# Iteration num 0
# Iteration num 100
# Considering feature: 113
# Considering feature set: [113]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 114
# Considering feature set: [114]
# Iteration num 0
# Considering feature: 115
# Considering feature set: [115]
# Iteration num 0
# Iteration num 100
# Considering feature: 116
# Considering feature set: [116]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 117
# Considering feature set: [117]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 118
# Considering feature set: [118]
# Iteration num 0
# Considering feature: 119
# Considering feature set: [119]
# Iteration num 0
# Iteration num 100
# Considering feature: 120
# Considering feature set: [120]
# Iteration num 0
# Iteration num 100
# Considering feature: 121
# Considering feature set: [121]
# Iteration num 0
# Iteration num 100
# Considering feature: 122
# Considering feature set: [122]
# Iteration num 0
# Iteration num 100
# Considering feature: 123
# Considering feature set: [123]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 124
# Considering feature set: [124]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 125
# Considering feature set: [125]
# Iteration num 0
# Iteration num 100
# Considering feature: 126
# Considering feature set: [126]
# Iteration num 0
# Iteration num 100
# Considering feature: 127
# Considering feature set: [127]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 128
# Considering feature set: [128]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 129
# Considering feature set: [129]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 130
# Considering feature set: [130]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 131
# Considering feature set: [131]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 132
# Considering feature set: [132]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 133
# Considering feature set: [133]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 134
# Considering feature set: [134]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 135
# Considering feature set: [135]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 136
# Considering feature set: [136]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 137
# Considering feature set: [137]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 138
# Considering feature set: [138]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 139
# Considering feature set: [139]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 140
# Considering feature set: [140]
# Iteration num 0
# Considering feature: 141
# Considering feature set: [141]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 142
# Considering feature set: [142]
# Iteration num 0
# Considering feature: 143
# Considering feature set: [143]
# Iteration num 0
# Iteration num 100
# Considering feature: 144
# Considering feature set: [144]
# Iteration num 0
# Considering feature: 145
# Considering feature set: [145]
# Iteration num 0
# Considering feature: 146
# Considering feature set: [146]
# Iteration num 0
# Considering feature: 147
# Considering feature set: [147]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 148
# Considering feature set: [148]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 149
# Considering feature set: [149]
# Iteration num 0
# Considering feature: 150
# Considering feature set: [150]
# Iteration num 0
# Iteration num 100
# Considering feature: 151
# Considering feature set: [151]
# Iteration num 0
# Iteration num 100
# Considering feature: 152
# Considering feature set: [152]
# Iteration num 0
# Iteration num 100
# Considering feature: 153
# Considering feature set: [153]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 154
# Considering feature set: [154]
# Iteration num 0
# Considering feature: 155
# Considering feature set: [155]
# Iteration num 0
# Considering feature: 156
# Considering feature set: [156]
# Iteration num 0
# Iteration num 100
# Considering feature: 157
# Considering feature set: [157]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 158
# Considering feature set: [158]
# Iteration num 0
# Iteration num 100
# Considering feature: 159
# Considering feature set: [159]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 160
# Considering feature set: [160]
# Iteration num 0
# Iteration num 100
# Considering feature: 161
# Considering feature set: [161]
# Iteration num 0
# Iteration num 100
# Considering feature: 162
# Considering feature set: [162]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 163
# Considering feature set: [163]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 164
# Considering feature set: [164]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 165
# Considering feature set: [165]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 166
# Considering feature set: [166]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 167
# Considering feature set: [167]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 168
# Considering feature set: [168]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 169
# Considering feature set: [169]
# Iteration num 0
# Considering feature: 0
# Considering feature set: [56, 0]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 1
# Considering feature set: [56, 1]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 2
# Considering feature set: [56, 2]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Iteration num 2400
# Iteration num 2500
# Iteration num 2600
# Iteration num 2700
# Iteration num 2800
# Iteration num 2900
# Iteration num 3000
# Iteration num 3100
# Iteration num 3200
# Iteration num 3300
# Iteration num 3400
# Iteration num 3500
# Iteration num 3600
# Iteration num 3700
# Iteration num 3800
# Iteration num 3900
# Iteration num 4000
# Iteration num 4100
# Iteration num 4200
# found new min cost for 2 features:
#                                 old min_cost 0.0005837662523706641, new min_cost: 0.0005835977789047612. diff = 1.6847346590292012e-07
#                                 old selected_features [56, 0], new selected_features: [56, 2]
# Considering feature: 3
# Considering feature set: [56, 3]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Iteration num 2400
# Iteration num 2500
# Iteration num 2600
# Iteration num 2700
# Iteration num 2800
# Considering feature: 4
# Considering feature set: [56, 4]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 5
# Considering feature set: [56, 5]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# found new min cost for 2 features:
#                                 old min_cost 0.0005835977789047612, new min_cost: 0.0005372576706670582. diff = 4.6340108237702946e-05
#                                 old selected_features [56, 2], new selected_features: [56, 5]
# Considering feature: 6
# Considering feature set: [56, 6]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 7
# Considering feature set: [56, 7]
# Iteration num 0
# Iteration num 100
# Considering feature: 8
# Considering feature set: [56, 8]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 9
# Considering feature set: [56, 9]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 10
# Considering feature set: [56, 10]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# found new min cost for 2 features:
#                                 old min_cost 0.0005372576706670582, new min_cost: 0.0005274510250608904. diff = 9.806645606167817e-06
#                                 old selected_features [56, 5], new selected_features: [56, 10]
# Considering feature: 11
# Considering feature set: [56, 11]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 12
# Considering feature set: [56, 12]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 13
# Considering feature set: [56, 13]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# found new min cost for 2 features:
#                                 old min_cost 0.0005274510250608904, new min_cost: 0.0005143350035359793. diff = 1.311602152491106e-05
#                                 old selected_features [56, 10], new selected_features: [56, 13]
# Considering feature: 14
# Considering feature set: [56, 14]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 15
# Considering feature set: [56, 15]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 16
# Considering feature set: [56, 16]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 17
# Considering feature set: [56, 17]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 18
# Considering feature set: [56, 18]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 19
# Considering feature set: [56, 19]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Considering feature: 20
# Considering feature set: [56, 20]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Considering feature: 21
# Considering feature set: [56, 21]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 22
# Considering feature set: [56, 22]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 23
# Considering feature set: [56, 23]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 24
# Considering feature set: [56, 24]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 25
# Considering feature set: [56, 25]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 26
# Considering feature set: [56, 26]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Considering feature: 27
# Considering feature set: [56, 27]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 28
# Considering feature set: [56, 28]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 29
# Considering feature set: [56, 29]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 30
# Considering feature set: [56, 30]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 31
# Considering feature set: [56, 31]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 32
# Considering feature set: [56, 32]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 33
# Considering feature set: [56, 33]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 34
# Considering feature set: [56, 34]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 35
# Considering feature set: [56, 35]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 36
# Considering feature set: [56, 36]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Considering feature: 37
# Considering feature set: [56, 37]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 38
# Considering feature set: [56, 38]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 39
# Considering feature set: [56, 39]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 40
# Considering feature set: [56, 40]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 41
# Considering feature set: [56, 41]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 42
# Considering feature set: [56, 42]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 43
# Considering feature set: [56, 43]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 44
# Considering feature set: [56, 44]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 45
# Considering feature set: [56, 45]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 46
# Considering feature set: [56, 46]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 47
# Considering feature set: [56, 47]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 48
# Considering feature set: [56, 48]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 49
# Considering feature set: [56, 49]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Considering feature: 50
# Considering feature set: [56, 50]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 51
# Considering feature set: [56, 51]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 52
# Considering feature set: [56, 52]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Considering feature: 53
# Considering feature set: [56, 53]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 54
# Considering feature set: [56, 54]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 55
# Considering feature set: [56, 55]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 57
# Considering feature set: [56, 57]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 58
# Considering feature set: [56, 58]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Iteration num 2400
# Iteration num 2500
# Iteration num 2600
# Iteration num 2700
# Iteration num 2800
# Iteration num 2900
# Iteration num 3000
# Iteration num 3100
# Iteration num 3200
# Iteration num 3300
# Considering feature: 59
# Considering feature set: [56, 59]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 60
# Considering feature set: [56, 60]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 61
# Considering feature set: [56, 61]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Iteration num 2400
# Iteration num 2500
# Iteration num 2600
# Iteration num 2700
# Iteration num 2800
# Iteration num 2900
# Iteration num 3000
# Iteration num 3100
# Iteration num 3200
# Iteration num 3300
# Iteration num 3400
# Iteration num 3500
# Iteration num 3600
# Iteration num 3700
# Iteration num 3800
# Iteration num 3900
# Iteration num 4000
# Iteration num 4100
# Iteration num 4200
# Iteration num 4300
# Iteration num 4400
# Iteration num 4500
# Iteration num 4600
# Considering feature: 62
# Considering feature set: [56, 62]
# Iteration num 0
# Iteration num 100
# Considering feature: 63
# Considering feature set: [56, 63]
# Iteration num 0
# Iteration num 100
# Considering feature: 64
# Considering feature set: [56, 64]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 65
# Considering feature set: [56, 65]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 66
# Considering feature set: [56, 66]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 67
# Considering feature set: [56, 67]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Iteration num 2400
# Considering feature: 68
# Considering feature set: [56, 68]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 69
# Considering feature set: [56, 69]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 70
# Considering feature set: [56, 70]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Considering feature: 71
# Considering feature set: [56, 71]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Considering feature: 72
# Considering feature set: [56, 72]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Considering feature: 73
# Considering feature set: [56, 73]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Considering feature: 74
# Considering feature set: [56, 74]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 75
# Considering feature set: [56, 75]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Considering feature: 76
# Considering feature set: [56, 76]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 77
# Considering feature set: [56, 77]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Iteration num 1900
# Iteration num 2000
# Iteration num 2100
# Iteration num 2200
# Iteration num 2300
# Considering feature: 78
# Considering feature set: [56, 78]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 79
# Considering feature set: [56, 79]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 80
# Considering feature set: [56, 80]
# Iteration num 0
# Iteration num 100
# Considering feature: 81
# Considering feature set: [56, 81]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 82
# Considering feature set: [56, 82]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 83
# Considering feature set: [56, 83]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 84
# Considering feature set: [56, 84]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 85
# Considering feature set: [56, 85]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 86
# Considering feature set: [56, 86]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 87
# Considering feature set: [56, 87]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 88
# Considering feature set: [56, 88]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 89
# Considering feature set: [56, 89]
# Iteration num 0
# Iteration num 100
# Considering feature: 90
# Considering feature set: [56, 90]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 91
# Considering feature set: [56, 91]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 92
# Considering feature set: [56, 92]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 93
# Considering feature set: [56, 93]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 94
# Considering feature set: [56, 94]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 95
# Considering feature set: [56, 95]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 96
# Considering feature set: [56, 96]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 97
# Considering feature set: [56, 97]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 98
# Considering feature set: [56, 98]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 99
# Considering feature set: [56, 99]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 100
# Considering feature set: [56, 100]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 101
# Considering feature set: [56, 101]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 102
# Considering feature set: [56, 102]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 103
# Considering feature set: [56, 103]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# ...
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 103
# Considering feature set: [56, 161, 38, 144, 103]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 104
# Considering feature set: [56, 161, 38, 144, 104]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 105
# Considering feature set: [56, 161, 38, 144, 105]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 106
# Considering feature set: [56, 161, 38, 144, 106]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 107
# Considering feature set: [56, 161, 38, 144, 107]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 108
# Considering feature set: [56, 161, 38, 144, 108]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 109
# Considering feature set: [56, 161, 38, 144, 109]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 110
# Considering feature set: [56, 161, 38, 144, 110]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 111
# Considering feature set: [56, 161, 38, 144, 111]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 112
# Considering feature set: [56, 161, 38, 144, 112]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 113
# Considering feature set: [56, 161, 38, 144, 113]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 114
# Considering feature set: [56, 161, 38, 144, 114]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 115
# Considering feature set: [56, 161, 38, 144, 115]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 116
# Considering feature set: [56, 161, 38, 144, 116]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 117
# Considering feature set: [56, 161, 38, 144, 117]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Considering feature: 118
# Considering feature set: [56, 161, 38, 144, 118]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 119
# Considering feature set: [56, 161, 38, 144, 119]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 120
# Considering feature set: [56, 161, 38, 144, 120]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Considering feature: 121
# Considering feature set: [56, 161, 38, 144, 121]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 122
# Considering feature set: [56, 161, 38, 144, 122]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 123
# Considering feature set: [56, 161, 38, 144, 123]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 124
# Considering feature set: [56, 161, 38, 144, 124]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 125
# Considering feature set: [56, 161, 38, 144, 125]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 126
# Considering feature set: [56, 161, 38, 144, 126]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 127
# Considering feature set: [56, 161, 38, 144, 127]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 128
# Considering feature set: [56, 161, 38, 144, 128]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 129
# Considering feature set: [56, 161, 38, 144, 129]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 130
# Considering feature set: [56, 161, 38, 144, 130]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 131
# Considering feature set: [56, 161, 38, 144, 131]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Considering feature: 132
# Considering feature set: [56, 161, 38, 144, 132]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 133
# Considering feature set: [56, 161, 38, 144, 133]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 134
# Considering feature set: [56, 161, 38, 144, 134]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 135
# Considering feature set: [56, 161, 38, 144, 135]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 136
# Considering feature set: [56, 161, 38, 144, 136]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 137
# Considering feature set: [56, 161, 38, 144, 137]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 138
# Considering feature set: [56, 161, 38, 144, 138]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 139
# Considering feature set: [56, 161, 38, 144, 139]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 140
# Considering feature set: [56, 161, 38, 144, 140]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 141
# Considering feature set: [56, 161, 38, 144, 141]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 142
# Considering feature set: [56, 161, 38, 144, 142]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Considering feature: 143
# Considering feature set: [56, 161, 38, 144, 143]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 145
# Considering feature set: [56, 161, 38, 144, 145]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 146
# Considering feature set: [56, 161, 38, 144, 146]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 147
# Considering feature set: [56, 161, 38, 144, 147]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 148
# Considering feature set: [56, 161, 38, 144, 148]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 149
# Considering feature set: [56, 161, 38, 144, 149]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 150
# Considering feature set: [56, 161, 38, 144, 150]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 151
# Considering feature set: [56, 161, 38, 144, 151]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 152
# Considering feature set: [56, 161, 38, 144, 152]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 153
# Considering feature set: [56, 161, 38, 144, 153]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 154
# Considering feature set: [56, 161, 38, 144, 154]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 155
# Considering feature set: [56, 161, 38, 144, 155]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 156
# Considering feature set: [56, 161, 38, 144, 156]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Iteration num 1600
# Iteration num 1700
# Iteration num 1800
# Considering feature: 157
# Considering feature set: [56, 161, 38, 144, 157]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Considering feature: 158
# Considering feature set: [56, 161, 38, 144, 158]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Considering feature: 159
# Considering feature set: [56, 161, 38, 144, 159]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Considering feature: 160
# Considering feature set: [56, 161, 38, 144, 160]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Iteration num 1500
# Considering feature: 162
# Considering feature set: [56, 161, 38, 144, 162]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Considering feature: 163
# Considering feature set: [56, 161, 38, 144, 163]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Considering feature: 164
# Considering feature set: [56, 161, 38, 144, 164]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 165
# Considering feature set: [56, 161, 38, 144, 165]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Considering feature: 166
# Considering feature set: [56, 161, 38, 144, 166]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Considering feature: 167
# Considering feature set: [56, 161, 38, 144, 167]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900
# Iteration num 1000
# Iteration num 1100
# Iteration num 1200
# Iteration num 1300
# Iteration num 1400
# Considering feature: 168
# Considering feature set: [56, 161, 38, 144, 168]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Considering feature: 169
# Considering feature set: [56, 161, 38, 144, 169]
# Iteration num 0
# Iteration num 100
# Iteration num 200
# Iteration num 300
# Iteration num 400
# Iteration num 500
# Iteration num 600
# Iteration num 700
# Iteration num 800
# Iteration num 900

# %%
for feature in ffs:
    print(feature_names[feature])
# Out:
# sqft_living * grade
# lat * long
# bathrooms * waterfront
# yr_built * zipcode
# bathrooms * sqft_above
